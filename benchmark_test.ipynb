# %%
import matplotlib.pyplot as plt

from metalearning_benchmarks.gp_benchmark import RBFGPBenchmark
from metalearning_benchmarks.polynomial_benchmark import PolynomialDeg10
from metalearning_benchmarks.quadratic1d_benchmark import Quadratic1D
from metalearning_benchmarks.sinusoid1d_benchmark import Sinusoid1D

# %%
benchmark = Sinusoid1D(
    n_task=128,  # number of tasks
    n_datapoints_per_task=128, # number of evaluations per task
    output_noise=0.01, # Gaussian noise with std-dev 0.01
    seed_task=1235, 
    seed_x=123, 
    seed_noise=1237
)
# Out:
# Generating tasks: 100%|██████████| 128/128 [00:00<00:00, 192564.89it/s]

# %%
for i in range(benchmark.x.shape[0]):
    task = benchmark.get_task_by_index(i)
    plt.scatter(task.x, task.y)
plt.show()
