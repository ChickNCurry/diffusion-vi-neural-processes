# %%
# %cd /home/chickencurry/diffusion-vi-neural-processes/neural-process/code
# Out:
# /home/chickencurry/diffusion-vi-neural-processes/neural-process/code

# %%
import torch
import torch.nn as nn
from adapter import MetaLearningBenchmarkDatasetAdapter
from matplotlib import pyplot as plt
from metalearning_benchmarks.sinusoid1d_benchmark import Sinusoid1D
from np import NeuralProcess
from torch.utils.data import DataLoader
from train import train
from utils import split_context_target
from visualize import (sample_latent_space, visualize_batch, visualize_decoder,
                       visualize_latent_space, visualize_losses)

# %%
device = None

try:
    import torch_directml
    device = torch_directml.device()
except ModuleNotFoundError:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
print(device)
# Out:
# privateuseone:0

# %%
benchmark = Sinusoid1D(
    n_task=2048,
    n_datapoints_per_task=128,
    output_noise=0.01,
    seed_task=1235, 
    seed_x=123, 
    seed_noise=1237
)

dataset = MetaLearningBenchmarkDatasetAdapter(benchmark)
dataloader = DataLoader(dataset=dataset, batch_size=128, shuffle=True, num_workers=10)
gen_dataloader = DataLoader(dataset=dataset, batch_size=1, shuffle=True, num_workers=10)
# Out:
# Generating tasks: 100%|██████████| 2048/2048 [00:00<00:00, 188388.15it/s]

# %%
visualize_batch(batch=next(iter(dataloader)))

# %%
model = NeuralProcess(x_dim=1, y_dim=1, r_dim=8, z_dim=8, h_dim=64).to(device)
# model.load_state_dict(torch.load('models/np.pth'))

optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)
recon_criterion = nn.MSELoss(reduction='mean')

# %%
visualize_decoder(model=model, device=device, z_dim=8)

# %%
total_recon_losses = []
total_kl_divs = []

# %%
recon_losses, kl_divs = train(
    model=model, 
    device=device, 
    dataloader=dataloader, 
    optimizer=optimizer, 
    recon_criterion=recon_criterion, 
    num_epochs=80
)

total_recon_losses.extend(recon_losses)
total_kl_divs.extend(kl_divs)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s, epoch=0, factor=0.1, kl_div=0.00129, loss=4.41, recon_loss=4.41]/home/chickencurry/miniconda3/envs/directml/lib/python3.11/site-packages/torch/optim/adam.py:522: UserWarning: The operator 'aten::_foreach_lerp_.Scalar' is not currently supported on the DML backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /__w/1/s/pytorch-directml-plugin/torch_directml/csrc/dml/dml_cpu_fallback.cpp:15.)
#   torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
# 100%|██████████| 16/16 [00:01<00:00,  8.64it/s, epoch=0, factor=0.1, kl_div=0.000498, loss=4.19, recon_loss=4.19]
# 100%|██████████| 16/16 [00:01<00:00, 10.07it/s, epoch=1, factor=0.127, kl_div=0.000847, loss=4.46, recon_loss=4.46]
# 100%|██████████| 16/16 [00:01<00:00, 10.07it/s, epoch=2, factor=0.9, kl_div=2.42e-5, loss=3.95, recon_loss=3.95]
# 100%|██████████| 16/16 [00:01<00:00,  9.74it/s, epoch=3, factor=0.222, kl_div=0.000873, loss=4.32, recon_loss=4.32]
# 100%|██████████| 16/16 [00:01<00:00, 10.39it/s, epoch=4, factor=0.153, kl_div=0.00109, loss=3.88, recon_loss=3.88]
# 100%|██████████| 16/16 [00:01<00:00, 10.65it/s, epoch=5, factor=0.475, kl_div=0.000403, loss=3.79, recon_loss=3.79]
# 100%|██████████| 16/16 [00:01<00:00, 10.30it/s, epoch=6, factor=0.624, kl_div=0.000351, loss=4.14, recon_loss=4.14]
# 100%|██████████| 16/16 [00:01<00:00, 10.60it/s, epoch=7, factor=0.297, kl_div=0.00141, loss=4.04, recon_loss=4.04]
# 100%|██████████| 16/16 [00:01<00:00, 10.39it/s, epoch=8, factor=0.263, kl_div=0.00153, loss=3.63, recon_loss=3.62]
# 100%|██████████| 16/16 [00:01<00:00, 10.63it/s, epoch=9, factor=0.1, kl_div=0.00502, loss=4.12, recon_loss=4.12]
# 100%|██████████| 16/16 [00:01<00:00, 10.36it/s, epoch=10, factor=0.1, kl_div=0.00459, loss=3.31, recon_loss=3.3]
# 100%|██████████| 16/16 [00:01<00:00, 10.50it/s, epoch=11, factor=0.159, kl_div=0.00407, loss=3.83, recon_loss=3.82]
# 100%|██████████| 16/16 [00:01<00:00, 10.29it/s, epoch=12, factor=0.377, kl_div=0.0025, loss=3.86, recon_loss=3.85]
# 100%|██████████| 16/16 [00:01<00:00,  9.64it/s, epoch=13, factor=0.66, kl_div=0.00106, loss=4.04, recon_loss=4.03]
# 100%|██████████| 16/16 [00:01<00:00,  9.95it/s, epoch=14, factor=0.309, kl_div=0.00277, loss=3.55, recon_loss=3.54]
# 100%|██████████| 16/16 [00:01<00:00, 10.57it/s, epoch=15, factor=0.85, kl_div=0.00032, loss=3.66, recon_loss=3.66]
# 100%|██████████| 16/16 [00:01<00:00, 10.13it/s, epoch=16, factor=0.16, kl_div=0.0212, loss=3.6, recon_loss=3.57]
# 100%|██████████| 16/16 [00:01<00:00, 10.36it/s, epoch=17, factor=0.249, kl_div=0.0113, loss=3.05, recon_loss=3.04]
# 100%|██████████| 16/16 [00:01<00:00, 10.16it/s, epoch=18, factor=0.655, kl_div=0.00369, loss=2.79, recon_loss=2.79]
# 100%|██████████| 16/16 [00:01<00:00, 10.05it/s, epoch=19, factor=0.157, kl_div=0.0443, loss=2.63, recon_loss=2.58]
# 100%|██████████| 16/16 [00:01<00:00,  9.82it/s, epoch=20, factor=0.263, kl_div=0.0475, loss=2.92, recon_loss=2.87]
# 100%|██████████| 16/16 [00:01<00:00, 10.20it/s, epoch=21, factor=0.344, kl_div=0.0313, loss=2.53, recon_loss=2.5]
# 100%|██████████| 16/16 [00:01<00:00, 10.48it/s, epoch=22, factor=0.227, kl_div=0.09, loss=2.45, recon_loss=2.36]
# 100%|██████████| 16/16 [00:01<00:00, 10.12it/s, epoch=23, factor=0.571, kl_div=0.0181, loss=2.84, recon_loss=2.82]
# 100%|██████████| 16/16 [00:01<00:00, 10.00it/s, epoch=24, factor=0.9, kl_div=0.00348, loss=2.58, recon_loss=2.57]
# 100%|██████████| 16/16 [00:01<00:00, 10.06it/s, epoch=25, factor=0.198, kl_div=0.232, loss=2.16, recon_loss=1.93]
# 100%|██████████| 16/16 [00:01<00:00,  9.99it/s, epoch=26, factor=0.1, kl_div=0.68, loss=2.38, recon_loss=1.7]
# 100%|██████████| 16/16 [00:01<00:00,  9.98it/s, epoch=27, factor=0.476, kl_div=0.0648, loss=1.35, recon_loss=1.28]
# 100%|██████████| 16/16 [00:01<00:00,  9.92it/s, epoch=28, factor=0.45, kl_div=0.0885, loss=1.1, recon_loss=1.01]
# 100%|██████████| 16/16 [00:01<00:00, 10.48it/s, epoch=29, factor=0.219, kl_div=0.365, loss=1.23, recon_loss=0.861]
# 100%|██████████| 16/16 [00:01<00:00, 10.65it/s, epoch=30, factor=0.208, kl_div=0.452, loss=1.27, recon_loss=0.818]
# 100%|██████████| 16/16 [00:01<00:00, 10.60it/s, epoch=31, factor=0.619, kl_div=0.0629, loss=0.868, recon_loss=0.805]
# 100%|██████████| 16/16 [00:01<00:00, 10.71it/s, epoch=32, factor=0.277, kl_div=0.207, loss=0.925, recon_loss=0.717]
# 100%|██████████| 16/16 [00:01<00:00, 10.47it/s, epoch=33, factor=0.523, kl_div=0.103, loss=0.836, recon_loss=0.733]
# 100%|██████████| 16/16 [00:01<00:00, 10.48it/s, epoch=34, factor=0.361, kl_div=0.226, loss=0.907, recon_loss=0.681]
# 100%|██████████| 16/16 [00:01<00:00, 10.48it/s, epoch=35, factor=0.9, kl_div=0.0103, loss=0.761, recon_loss=0.751]
# 100%|██████████| 16/16 [00:01<00:00, 10.12it/s, epoch=36, factor=0.672, kl_div=0.0529, loss=0.737, recon_loss=0.684]
# 100%|██████████| 16/16 [00:01<00:00, 10.31it/s, epoch=37, factor=0.302, kl_div=0.249, loss=0.851, recon_loss=0.602]
# 100%|██████████| 16/16 [00:01<00:00, 10.70it/s, epoch=38, factor=0.399, kl_div=0.146, loss=0.721, recon_loss=0.575]
# 100%|██████████| 16/16 [00:01<00:00, 10.88it/s, epoch=39, factor=0.353, kl_div=0.204, loss=0.747, recon_loss=0.542]
# 100%|██████████| 16/16 [00:01<00:00, 10.69it/s, epoch=40, factor=0.561, kl_div=0.0627, loss=0.516, recon_loss=0.453]
# 100%|██████████| 16/16 [00:01<00:00, 10.50it/s, epoch=41, factor=0.228, kl_div=0.276, loss=0.741, recon_loss=0.464]
# 100%|██████████| 16/16 [00:01<00:00, 10.49it/s, epoch=42, factor=0.9, kl_div=0.0094, loss=0.558, recon_loss=0.548]
# 100%|██████████| 16/16 [00:01<00:00, 10.54it/s, epoch=43, factor=0.9, kl_div=0.012, loss=0.504, recon_loss=0.492]
# 100%|██████████| 16/16 [00:01<00:00, 10.39it/s, epoch=44, factor=0.851, kl_div=0.0202, loss=0.377, recon_loss=0.357]
# 100%|██████████| 16/16 [00:01<00:00, 10.68it/s, epoch=45, factor=0.735, kl_div=0.0419, loss=0.527, recon_loss=0.485]
# 100%|██████████| 16/16 [00:01<00:00, 10.43it/s, epoch=46, factor=0.589, kl_div=0.0603, loss=0.683, recon_loss=0.623]
# 100%|██████████| 16/16 [00:01<00:00, 10.47it/s, epoch=47, factor=0.376, kl_div=0.121, loss=0.574, recon_loss=0.453]
# 100%|██████████| 16/16 [00:01<00:00, 10.14it/s, epoch=48, factor=0.366, kl_div=0.164, loss=0.6, recon_loss=0.435]
# 100%|██████████| 16/16 [00:01<00:00, 10.31it/s, epoch=49, factor=0.201, kl_div=0.437, loss=0.868, recon_loss=0.432]
# 100%|██████████| 16/16 [00:01<00:00, 10.72it/s, epoch=50, factor=0.565, kl_div=0.0753, loss=0.494, recon_loss=0.419]
# 100%|██████████| 16/16 [00:01<00:00, 10.84it/s, epoch=51, factor=0.213, kl_div=0.418, loss=0.777, recon_loss=0.359]
# 100%|██████████| 16/16 [00:01<00:00, 10.83it/s, epoch=52, factor=0.717, kl_div=0.0356, loss=0.376, recon_loss=0.341]
# 100%|██████████| 16/16 [00:01<00:00, 10.69it/s, epoch=53, factor=0.565, kl_div=0.0762, loss=0.523, recon_loss=0.447]
# 100%|██████████| 16/16 [00:01<00:00, 10.81it/s, epoch=54, factor=0.1, kl_div=0.81, loss=1.21, recon_loss=0.398]
# 100%|██████████| 16/16 [00:01<00:00, 10.35it/s, epoch=55, factor=0.459, kl_div=0.138, loss=0.61, recon_loss=0.472]
# 100%|██████████| 16/16 [00:01<00:00,  9.97it/s, epoch=56, factor=0.312, kl_div=0.212, loss=0.692, recon_loss=0.48]
# 100%|██████████| 16/16 [00:01<00:00, 10.38it/s, epoch=57, factor=0.857, kl_div=0.0159, loss=0.355, recon_loss=0.339]
# 100%|██████████| 16/16 [00:01<00:00, 10.35it/s, epoch=58, factor=0.554, kl_div=0.0776, loss=0.461, recon_loss=0.383]
# 100%|██████████| 16/16 [00:01<00:00, 10.77it/s, epoch=59, factor=0.442, kl_div=0.128, loss=0.519, recon_loss=0.391]
# 100%|██████████| 16/16 [00:01<00:00, 10.65it/s, epoch=60, factor=0.639, kl_div=0.0709, loss=0.438, recon_loss=0.368]
# 100%|██████████| 16/16 [00:01<00:00, 10.42it/s, epoch=61, factor=0.58, kl_div=0.0857, loss=0.468, recon_loss=0.382]
# 100%|██████████| 16/16 [00:01<00:00, 10.17it/s, epoch=62, factor=0.5, kl_div=0.0816, loss=0.469, recon_loss=0.387]
# 100%|██████████| 16/16 [00:01<00:00,  9.81it/s, epoch=63, factor=0.413, kl_div=0.131, loss=0.538, recon_loss=0.407]
# 100%|██████████| 16/16 [00:01<00:00, 10.40it/s, epoch=64, factor=0.631, kl_div=0.0568, loss=0.392, recon_loss=0.335]
# 100%|██████████| 16/16 [00:01<00:00,  9.06it/s, epoch=65, factor=0.1, kl_div=0.887, loss=1.28, recon_loss=0.398]
# 100%|██████████| 16/16 [00:01<00:00, 10.17it/s, epoch=66, factor=0.326, kl_div=0.132, loss=0.503, recon_loss=0.371]
# 100%|██████████| 16/16 [00:01<00:00, 10.01it/s, epoch=67, factor=0.153, kl_div=0.364, loss=0.719, recon_loss=0.354]
# 100%|██████████| 16/16 [00:01<00:00, 10.18it/s, epoch=68, factor=0.237, kl_div=0.25, loss=0.682, recon_loss=0.432]
# 100%|██████████| 16/16 [00:01<00:00, 10.71it/s, epoch=69, factor=0.431, kl_div=0.124, loss=0.521, recon_loss=0.397]
# 100%|██████████| 16/16 [00:01<00:00, 10.24it/s, epoch=70, factor=0.1, kl_div=1.02, loss=1.42, recon_loss=0.393]
# 100%|██████████| 16/16 [00:01<00:00, 10.77it/s, epoch=71, factor=0.549, kl_div=0.0839, loss=0.41, recon_loss=0.326]
# 100%|██████████| 16/16 [00:01<00:00, 10.66it/s, epoch=72, factor=0.1, kl_div=0.948, loss=1.34, recon_loss=0.394]
# 100%|██████████| 16/16 [00:01<00:00, 10.88it/s, epoch=73, factor=0.349, kl_div=0.175, loss=0.559, recon_loss=0.384]
# 100%|██████████| 16/16 [00:01<00:00, 10.56it/s, epoch=74, factor=0.572, kl_div=0.0764, loss=0.377, recon_loss=0.301]
# 100%|██████████| 16/16 [00:01<00:00, 10.81it/s, epoch=75, factor=0.682, kl_div=0.0431, loss=0.356, recon_loss=0.313]
# 100%|██████████| 16/16 [00:01<00:00, 10.58it/s, epoch=76, factor=0.554, kl_div=0.0769, loss=0.383, recon_loss=0.306]
# 100%|██████████| 16/16 [00:01<00:00, 10.98it/s, epoch=77, factor=0.871, kl_div=0.0153, loss=0.359, recon_loss=0.344]
# 100%|██████████| 16/16 [00:01<00:00, 10.85it/s, epoch=78, factor=0.618, kl_div=0.0486, loss=0.389, recon_loss=0.34]
# 100%|██████████| 16/16 [00:01<00:00, 10.22it/s, epoch=79, factor=0.419, kl_div=0.135, loss=0.502, recon_loss=0.367]

# %%
visualize_losses(recon_losses=recon_losses, kl_divs=kl_divs)

# %%
mus, logvars = sample_latent_space(model=model, device=device, dataloader=gen_dataloader, num_samples=1000)
# Out:
# 1001it [00:02, 428.81it/s]

# %%
visualize_latent_space(
    mus=mus, 
    logvars=logvars, 
    dim_1=0, 
    dim_2=1
)

# %%
sample = next(iter(gen_dataloader))
sequence = torch.cat(sample, dim=-1).to(device)
factor = 0.1 # max(min(0.9, np.random.random()), 0.1)
context, target = split_context_target(sequence, factor)

n_samples = 10

mus, logvars, _, _ = model.sample(context, target[:, :, 0:1], n_samples)
print(mus[0].shape)
print(target.shape)
plt.scatter(context[0, :, 0].cpu().detach().numpy(), context[0, :, 1].cpu().detach().numpy(), c="red")

for i in range(n_samples):
    x = target[0, :, 0].cpu().detach().numpy()
    y = mus[i][0, :, 0].cpu().detach().numpy()
    plt.scatter(x, y)

plt.show()
# Out:
# torch.Size([1, 116, 1])
# torch.Size([1, 116, 2])

# %%
torch.save(model.state_dict(), 'models/np.pth')
