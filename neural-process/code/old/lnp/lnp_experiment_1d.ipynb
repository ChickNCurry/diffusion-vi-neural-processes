# %%
import torch
import wandb
from latent_neural_process import LatentNeuralProcess
from matplotlib import pyplot as plt
from metalearning_benchmarks.sinusoid1d_benchmark import Sinusoid1D
from train_val import train_and_validate
from utils import Config, DataModule, MetaLearningDataset, split_context_target

# %%
device = None

try:
    import torch_directml
    device = torch_directml.device()
except ModuleNotFoundError:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
print(device)
# Out:
# privateuseone:0

# %%
config = Config(
    task="sinusoid1d",
    n_task=4096,
    n_datapoints_per_task=128,
    output_noise=0.01,
    seed_task=1235, 
    seed_x=123, 
    seed_noise=1237,
    x_dim=1,
    y_dim=1,
    r_dim=32,
    z_dim=32,
    h_dim=32,
    split=(0.8, 0.2),
    batch_size=128,
    num_epochs=100,
    learning_rate=0.005,
)

# %%
wandb.init(project="neural-process", config=config.asdict())
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: max-burzer (max-burzer-karlsruhe-institute-of-technology). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.0
# Run data is saved locally in <code>/home/chickencurry/diffusion-vi-neural-processes/neural-process/code/new/wandb/run-20240917_191626-2sivcssa</code>
# Syncing run <strong><a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/neural-process/runs/2sivcssa' target="_blank">smooth-durian-5</a></strong> to <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/neural-process' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/neural-process' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/neural-process</a>
#  View run at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/neural-process/runs/2sivcssa' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/neural-process/runs/2sivcssa</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/neural-process/runs/2sivcssa?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
benchmark = Sinusoid1D(
    n_task=config.n_task,
    n_datapoints_per_task=config.n_datapoints_per_task,
    output_noise=config.output_noise,
    seed_task=config.seed_task, 
    seed_x=config.seed_x, 
    seed_noise=config.seed_noise,
)

dataset = MetaLearningDataset(benchmark)

data_module = DataModule(
    batch_size=config.batch_size,
    dataset_and_split=(dataset, config.split),
)
# Out:
# Generating tasks: 100%|██████████| 4096/4096 [00:00<00:00, 198983.87it/s]

# %%
model = LatentNeuralProcess(
    x_dim=config.x_dim, 
    y_dim=config.y_dim, 
    r_dim=config.r_dim, 
    z_dim=config.z_dim, 
    h_dim=config.h_dim, 
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)

# %%
avg_train_neg_log_likes = []
avg_train_kl_divs = []

avg_val_neg_log_likes = []
avg_val_kl_divs = []

# %%
losses = train_and_validate(
    model=model,
    data_module=data_module,
    num_epochs=config.num_epochs,
    device=device,
    optimizer=optimizer,
)

avg_train_neg_log_likes.extend(losses[0])
avg_train_kl_divs.extend(losses[1])

avg_val_neg_log_likes.extend(losses[2])
avg_val_kl_divs.extend(losses[3])
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]/home/chickencurry/miniconda3/envs/directml/lib/python3.11/site-packages/torch/optim/adam.py:522: UserWarning: The operator 'aten::_foreach_lerp_.Scalar' is not currently supported on the DML backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /__w/1/s/pytorch-directml-plugin/torch_directml/csrc/dml/dml_cpu_fallback.cpp:15.)
#   torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
# 100%|██████████| 26/26 [00:03<00:00,  7.31it/s, epoch=0, kl_div=0.00208, loss=270, recon_loss=270]
# 100%|██████████| 7/7 [00:00<00:00, 17.09it/s, epoch=0, kl_div=0.0218, loss=273, recon_loss=273]
# 100%|██████████| 26/26 [00:03<00:00,  8.33it/s, epoch=1, kl_div=1.57, loss=245, recon_loss=244]
# 100%|██████████| 7/7 [00:00<00:00, 16.83it/s, epoch=1, kl_div=0.171, loss=244, recon_loss=244]
# 100%|██████████| 26/26 [00:03<00:00,  8.32it/s, epoch=2, kl_div=0.135, loss=249, recon_loss=249]
# 100%|██████████| 7/7 [00:00<00:00, 15.73it/s, epoch=2, kl_div=0.119, loss=229, recon_loss=229]
# 100%|██████████| 26/26 [00:03<00:00,  8.41it/s, epoch=3, kl_div=0.47, loss=211, recon_loss=210]
# 100%|██████████| 7/7 [00:00<00:00, 17.89it/s, epoch=3, kl_div=0.0441, loss=229, recon_loss=229]
# 100%|██████████| 26/26 [00:03<00:00,  8.65it/s, epoch=4, kl_div=1.72, loss=218, recon_loss=216]
# 100%|██████████| 7/7 [00:00<00:00, 17.16it/s, epoch=4, kl_div=0.293, loss=225, recon_loss=224]
# 100%|██████████| 26/26 [00:03<00:00,  8.06it/s, epoch=5, kl_div=0.255, loss=226, recon_loss=226]
# 100%|██████████| 7/7 [00:00<00:00, 17.08it/s, epoch=5, kl_div=0.0593, loss=220, recon_loss=220]
# 100%|██████████| 26/26 [00:03<00:00,  8.36it/s, epoch=6, kl_div=3.33, loss=217, recon_loss=214]
# 100%|██████████| 7/7 [00:00<00:00, 17.43it/s, epoch=6, kl_div=0.0671, loss=213, recon_loss=212]
# 100%|██████████| 26/26 [00:03<00:00,  8.24it/s, epoch=7, kl_div=3.3, loss=212, recon_loss=209]
# 100%|██████████| 7/7 [00:00<00:00, 16.23it/s, epoch=7, kl_div=1.28, loss=220, recon_loss=219]
# 100%|██████████| 26/26 [00:03<00:00,  8.10it/s, epoch=8, kl_div=9.89, loss=193, recon_loss=183]
# 100%|██████████| 7/7 [00:00<00:00, 16.61it/s, epoch=8, kl_div=1.94, loss=205, recon_loss=203]
# 100%|██████████| 26/26 [00:03<00:00,  8.20it/s, epoch=9, kl_div=13, loss=153, recon_loss=140]
# 100%|██████████| 7/7 [00:00<00:00, 17.29it/s, epoch=9, kl_div=5.06, loss=166, recon_loss=161]
# 100%|██████████| 26/26 [00:03<00:00,  8.08it/s, epoch=10, kl_div=2.12, loss=97, recon_loss=94.9]
# 100%|██████████| 7/7 [00:00<00:00, 16.57it/s, epoch=10, kl_div=35.3, loss=156, recon_loss=121]
# 100%|██████████| 26/26 [00:03<00:00,  8.38it/s, epoch=11, kl_div=1.03, loss=53.9, recon_loss=52.9]
# 100%|██████████| 7/7 [00:00<00:00, 16.34it/s, epoch=11, kl_div=2.19, loss=64.5, recon_loss=62.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.28it/s, epoch=12, kl_div=1.68, loss=60, recon_loss=58.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.34it/s, epoch=12, kl_div=2.15, loss=72, recon_loss=69.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.44it/s, epoch=13, kl_div=9.36, loss=64.6, recon_loss=55.2]
# 100%|██████████| 7/7 [00:00<00:00, 17.58it/s, epoch=13, kl_div=8.9, loss=49.5, recon_loss=40.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.29it/s, epoch=14, kl_div=0.4, loss=79.7, recon_loss=79.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.86it/s, epoch=14, kl_div=0.834, loss=63.7, recon_loss=62.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.28it/s, epoch=15, kl_div=1.78, loss=33.2, recon_loss=31.4]
# 100%|██████████| 7/7 [00:00<00:00, 16.20it/s, epoch=15, kl_div=3.26, loss=20.5, recon_loss=17.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.15it/s, epoch=16, kl_div=0.387, loss=12.7, recon_loss=12.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.97it/s, epoch=16, kl_div=0.899, loss=36.2, recon_loss=35.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.20it/s, epoch=17, kl_div=6.71, loss=27, recon_loss=20.3]
# 100%|██████████| 7/7 [00:00<00:00, 15.86it/s, epoch=17, kl_div=21.8, loss=30, recon_loss=8.19]
# 100%|██████████| 26/26 [00:03<00:00,  8.30it/s, epoch=18, kl_div=24.3, loss=47.6, recon_loss=23.4]
# 100%|██████████| 7/7 [00:00<00:00, 15.77it/s, epoch=18, kl_div=0.401, loss=1.35, recon_loss=0.944]
# 100%|██████████| 26/26 [00:03<00:00,  8.39it/s, epoch=19, kl_div=0.839, loss=9.71, recon_loss=8.87]
# 100%|██████████| 7/7 [00:00<00:00, 16.28it/s, epoch=19, kl_div=4.59, loss=13.2, recon_loss=8.57]
# 100%|██████████| 26/26 [00:03<00:00,  8.51it/s, epoch=20, kl_div=37.6, loss=34.6, recon_loss=-3.05]
# 100%|██████████| 7/7 [00:00<00:00, 15.38it/s, epoch=20, kl_div=0.668, loss=28, recon_loss=27.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.58it/s, epoch=21, kl_div=8.66, loss=2.27, recon_loss=-6.39]
# 100%|██████████| 7/7 [00:00<00:00, 16.74it/s, epoch=21, kl_div=0.544, loss=-14.5, recon_loss=-15]
# 100%|██████████| 26/26 [00:03<00:00,  8.16it/s, epoch=22, kl_div=11.5, loss=22.2, recon_loss=10.7]
# 100%|██████████| 7/7 [00:00<00:00, 16.06it/s, epoch=22, kl_div=1.68, loss=10.2, recon_loss=8.55]
# 100%|██████████| 26/26 [00:03<00:00,  8.26it/s, epoch=23, kl_div=4.49, loss=-36.5, recon_loss=-41]
# 100%|██████████| 7/7 [00:00<00:00, 16.51it/s, epoch=23, kl_div=15.8, loss=5.16, recon_loss=-10.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.35it/s, epoch=24, kl_div=9.78, loss=-4.85, recon_loss=-14.6]
# 100%|██████████| 7/7 [00:00<00:00, 17.11it/s, epoch=24, kl_div=1.32, loss=4.88, recon_loss=3.55]
# 100%|██████████| 26/26 [00:03<00:00,  8.28it/s, epoch=25, kl_div=1.44, loss=-15, recon_loss=-16.4]
# 100%|██████████| 7/7 [00:00<00:00, 16.06it/s, epoch=25, kl_div=0.931, loss=-7.59, recon_loss=-8.52]
# 100%|██████████| 26/26 [00:03<00:00,  8.38it/s, epoch=26, kl_div=1.99, loss=-1.6, recon_loss=-3.59]
# 100%|██████████| 7/7 [00:00<00:00, 15.23it/s, epoch=26, kl_div=1.38, loss=-5.51, recon_loss=-6.88]
# 100%|██████████| 26/26 [00:03<00:00,  8.47it/s, epoch=27, kl_div=1.2, loss=-37.1, recon_loss=-38.2]
# 100%|██████████| 7/7 [00:00<00:00, 17.43it/s, epoch=27, kl_div=38.4, loss=5.56, recon_loss=-32.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.46it/s, epoch=28, kl_div=7.78, loss=-1.26, recon_loss=-9.05]
# 100%|██████████| 7/7 [00:00<00:00, 16.94it/s, epoch=28, kl_div=8.95, loss=0.996, recon_loss=-7.96]
# 100%|██████████| 26/26 [00:03<00:00,  8.63it/s, epoch=29, kl_div=6.08, loss=-24.6, recon_loss=-30.6]
# 100%|██████████| 7/7 [00:00<00:00, 15.15it/s, epoch=29, kl_div=4.51, loss=-14.8, recon_loss=-19.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.48it/s, epoch=30, kl_div=4.92, loss=7.78, recon_loss=2.86]
# 100%|██████████| 7/7 [00:00<00:00, 16.80it/s, epoch=30, kl_div=12.5, loss=6.64, recon_loss=-5.89]
# 100%|██████████| 26/26 [00:03<00:00,  8.49it/s, epoch=31, kl_div=0.655, loss=-19, recon_loss=-19.7]
# 100%|██████████| 7/7 [00:00<00:00, 17.98it/s, epoch=31, kl_div=2.45, loss=-26.5, recon_loss=-28.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.43it/s, epoch=32, kl_div=1.73, loss=-3.88, recon_loss=-5.61]
# 100%|██████████| 7/7 [00:00<00:00, 17.18it/s, epoch=32, kl_div=17.6, loss=-8.4, recon_loss=-26.1]
# 100%|██████████| 26/26 [00:03<00:00,  8.40it/s, epoch=33, kl_div=0.708, loss=-37.1, recon_loss=-37.9]
# 100%|██████████| 7/7 [00:00<00:00, 17.23it/s, epoch=33, kl_div=4.14, loss=-19, recon_loss=-23.2]
# 100%|██████████| 26/26 [00:03<00:00,  8.59it/s, epoch=34, kl_div=19, loss=-1.79, recon_loss=-20.8]
# 100%|██████████| 7/7 [00:00<00:00, 15.10it/s, epoch=34, kl_div=29.3, loss=-10, recon_loss=-39.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.40it/s, epoch=35, kl_div=0.576, loss=-36.6, recon_loss=-37.2]
# 100%|██████████| 7/7 [00:00<00:00, 15.74it/s, epoch=35, kl_div=27.9, loss=-13.1, recon_loss=-41]
# 100%|██████████| 26/26 [00:03<00:00,  8.41it/s, epoch=36, kl_div=0.434, loss=-43.4, recon_loss=-43.9]
# 100%|██████████| 7/7 [00:00<00:00, 16.02it/s, epoch=36, kl_div=1.14, loss=-3.89, recon_loss=-5.03]
# 100%|██████████| 26/26 [00:03<00:00,  8.03it/s, epoch=37, kl_div=2.76, loss=-26.6, recon_loss=-29.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.30it/s, epoch=37, kl_div=0.354, loss=-18.5, recon_loss=-18.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.39it/s, epoch=38, kl_div=15.8, loss=-16.9, recon_loss=-32.8]
# 100%|██████████| 7/7 [00:00<00:00, 16.19it/s, epoch=38, kl_div=0.757, loss=-43.8, recon_loss=-44.5]
# 100%|██████████| 26/26 [00:03<00:00,  7.73it/s, epoch=39, kl_div=34.8, loss=15.4, recon_loss=-19.4]
# 100%|██████████| 7/7 [00:00<00:00, 16.35it/s, epoch=39, kl_div=2.79, loss=-39.1, recon_loss=-41.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.35it/s, epoch=40, kl_div=60.9, loss=27.4, recon_loss=-33.5]
# 100%|██████████| 7/7 [00:00<00:00, 15.04it/s, epoch=40, kl_div=2.99, loss=-6.77, recon_loss=-9.76]
# 100%|██████████| 26/26 [00:03<00:00,  8.37it/s, epoch=41, kl_div=5.54, loss=-38.8, recon_loss=-44.3]
# 100%|██████████| 7/7 [00:00<00:00, 15.85it/s, epoch=41, kl_div=4.27, loss=-37.4, recon_loss=-41.7]
# 100%|██████████| 26/26 [00:03<00:00,  8.12it/s, epoch=42, kl_div=0.323, loss=-13.9, recon_loss=-14.2]
# 100%|██████████| 7/7 [00:00<00:00, 16.17it/s, epoch=42, kl_div=23.4, loss=-5.92, recon_loss=-29.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.51it/s, epoch=43, kl_div=5.54, loss=-56, recon_loss=-61.6]
# 100%|██████████| 7/7 [00:00<00:00, 15.87it/s, epoch=43, kl_div=9.84, loss=-33.3, recon_loss=-43.1]
# 100%|██████████| 26/26 [00:03<00:00,  8.43it/s, epoch=44, kl_div=5.66, loss=-31.7, recon_loss=-37.4]
# 100%|██████████| 7/7 [00:00<00:00, 16.98it/s, epoch=44, kl_div=4.58, loss=-32.7, recon_loss=-37.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.44it/s, epoch=45, kl_div=2.39, loss=-19, recon_loss=-21.4]
# 100%|██████████| 7/7 [00:00<00:00, 16.11it/s, epoch=45, kl_div=3.08, loss=-37.1, recon_loss=-40.2]
# 100%|██████████| 26/26 [00:03<00:00,  8.47it/s, epoch=46, kl_div=0.569, loss=-28.2, recon_loss=-28.7]
# 100%|██████████| 7/7 [00:00<00:00, 15.96it/s, epoch=46, kl_div=38.8, loss=16, recon_loss=-22.8]
# 100%|██████████| 26/26 [00:03<00:00,  8.26it/s, epoch=47, kl_div=6.13, loss=-61.5, recon_loss=-67.7]
# 100%|██████████| 7/7 [00:00<00:00, 15.98it/s, epoch=47, kl_div=8.18, loss=-31.1, recon_loss=-39.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.36it/s, epoch=48, kl_div=5.02, loss=-48.6, recon_loss=-53.6]
# 100%|██████████| 7/7 [00:00<00:00, 15.54it/s, epoch=48, kl_div=4.89, loss=-42.6, recon_loss=-47.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.44it/s, epoch=49, kl_div=8.64, loss=-13, recon_loss=-21.6]
# 100%|██████████| 7/7 [00:00<00:00, 16.24it/s, epoch=49, kl_div=1.29, loss=-29.2, recon_loss=-30.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.32it/s, epoch=50, kl_div=0.323, loss=-47.4, recon_loss=-47.7]
# 100%|██████████| 7/7 [00:00<00:00, 17.32it/s, epoch=50, kl_div=4.79, loss=-27.9, recon_loss=-32.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.45it/s, epoch=51, kl_div=41.5, loss=-18.4, recon_loss=-59.9]
# 100%|██████████| 7/7 [00:00<00:00, 15.17it/s, epoch=51, kl_div=2.77, loss=-48, recon_loss=-50.8]
# 100%|██████████| 26/26 [00:03<00:00,  8.12it/s, epoch=52, kl_div=7.2, loss=-47.3, recon_loss=-54.5]
# 100%|██████████| 7/7 [00:00<00:00, 14.76it/s, epoch=52, kl_div=13.8, loss=-26.3, recon_loss=-40.1]
# 100%|██████████| 26/26 [00:03<00:00,  7.75it/s, epoch=53, kl_div=0.549, loss=-49.4, recon_loss=-50]
# 100%|██████████| 7/7 [00:00<00:00, 15.35it/s, epoch=53, kl_div=3.29, loss=-45.3, recon_loss=-48.6]
# 100%|██████████| 26/26 [00:03<00:00,  7.82it/s, epoch=54, kl_div=0.774, loss=-42.9, recon_loss=-43.7]
# 100%|██████████| 7/7 [00:00<00:00, 15.57it/s, epoch=54, kl_div=27.9, loss=-7.48, recon_loss=-35.4]
# 100%|██████████| 26/26 [00:03<00:00,  7.52it/s, epoch=55, kl_div=1.76, loss=-56.9, recon_loss=-58.6]
# 100%|██████████| 7/7 [00:00<00:00, 16.04it/s, epoch=55, kl_div=0.674, loss=-44.9, recon_loss=-45.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.25it/s, epoch=56, kl_div=3.29, loss=-21.9, recon_loss=-25.1]
# 100%|██████████| 7/7 [00:00<00:00, 14.84it/s, epoch=56, kl_div=3.23, loss=-16.7, recon_loss=-19.9]
# 100%|██████████| 26/26 [00:03<00:00,  7.84it/s, epoch=57, kl_div=22.2, loss=-26.5, recon_loss=-48.7]
# 100%|██████████| 7/7 [00:00<00:00, 14.27it/s, epoch=57, kl_div=0.406, loss=-33.3, recon_loss=-33.7]
# 100%|██████████| 26/26 [00:03<00:00,  7.76it/s, epoch=58, kl_div=45, loss=-6.31, recon_loss=-51.3]
# 100%|██████████| 7/7 [00:00<00:00, 15.25it/s, epoch=58, kl_div=8.88, loss=-51, recon_loss=-59.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.36it/s, epoch=59, kl_div=5.49, loss=-44.7, recon_loss=-50.2]
# 100%|██████████| 7/7 [00:00<00:00, 16.48it/s, epoch=59, kl_div=13.8, loss=0.58, recon_loss=-13.2]
# 100%|██████████| 26/26 [00:03<00:00,  8.32it/s, epoch=60, kl_div=36.2, loss=-17.6, recon_loss=-53.9]
# 100%|██████████| 7/7 [00:00<00:00, 15.99it/s, epoch=60, kl_div=15.5, loss=-27.8, recon_loss=-43.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.29it/s, epoch=61, kl_div=1.32, loss=-44.5, recon_loss=-45.9]
# 100%|██████████| 7/7 [00:00<00:00, 15.92it/s, epoch=61, kl_div=5.43, loss=-26.4, recon_loss=-31.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.35it/s, epoch=62, kl_div=40.9, loss=-27.6, recon_loss=-68.4]
# 100%|██████████| 7/7 [00:00<00:00, 15.56it/s, epoch=62, kl_div=3.95, loss=-37.3, recon_loss=-41.2]
# 100%|██████████| 26/26 [00:03<00:00,  8.33it/s, epoch=63, kl_div=6.34, loss=-77.6, recon_loss=-83.9]
# 100%|██████████| 7/7 [00:00<00:00, 16.12it/s, epoch=63, kl_div=1.49, loss=-69.1, recon_loss=-70.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.44it/s, epoch=64, kl_div=2.98, loss=-42.4, recon_loss=-45.4]
# 100%|██████████| 7/7 [00:00<00:00, 15.16it/s, epoch=64, kl_div=0.428, loss=-41.6, recon_loss=-42]
# 100%|██████████| 26/26 [00:03<00:00,  8.29it/s, epoch=65, kl_div=15.3, loss=-24.4, recon_loss=-39.7]
# 100%|██████████| 7/7 [00:00<00:00, 15.52it/s, epoch=65, kl_div=1, loss=-36.6, recon_loss=-37.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.00it/s, epoch=66, kl_div=0.327, loss=-14, recon_loss=-14.4]
# 100%|██████████| 7/7 [00:00<00:00, 15.42it/s, epoch=66, kl_div=4, loss=-18.6, recon_loss=-22.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.24it/s, epoch=67, kl_div=2.54, loss=-59.4, recon_loss=-61.9]
# 100%|██████████| 7/7 [00:00<00:00, 16.40it/s, epoch=67, kl_div=0.595, loss=-56.2, recon_loss=-56.8]
# 100%|██████████| 26/26 [00:03<00:00,  8.13it/s, epoch=68, kl_div=6.13, loss=-39.1, recon_loss=-45.2]
# 100%|██████████| 7/7 [00:00<00:00, 15.76it/s, epoch=68, kl_div=0.796, loss=-43.7, recon_loss=-44.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.34it/s, epoch=69, kl_div=1.1, loss=-63.2, recon_loss=-64.3]
# 100%|██████████| 7/7 [00:00<00:00, 15.93it/s, epoch=69, kl_div=28.2, loss=-21.2, recon_loss=-49.4]
# 100%|██████████| 26/26 [00:03<00:00,  8.12it/s, epoch=70, kl_div=43.6, loss=-6, recon_loss=-49.6]
# 100%|██████████| 7/7 [00:00<00:00, 16.08it/s, epoch=70, kl_div=2.95, loss=-27.2, recon_loss=-30.2]
# 100%|██████████| 26/26 [00:03<00:00,  8.12it/s, epoch=71, kl_div=0.645, loss=-59.8, recon_loss=-60.4]
# 100%|██████████| 7/7 [00:00<00:00, 15.39it/s, epoch=71, kl_div=11.3, loss=-32.2, recon_loss=-43.4]
# 100%|██████████| 26/26 [00:03<00:00,  8.22it/s, epoch=72, kl_div=5.41, loss=-52.9, recon_loss=-58.3]
# 100%|██████████| 7/7 [00:00<00:00, 15.91it/s, epoch=72, kl_div=0.697, loss=-52.2, recon_loss=-52.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.16it/s, epoch=73, kl_div=1.66, loss=-66.1, recon_loss=-67.8]
# 100%|██████████| 7/7 [00:00<00:00, 15.75it/s, epoch=73, kl_div=34.6, loss=-33.9, recon_loss=-68.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.08it/s, epoch=74, kl_div=0.787, loss=-51.5, recon_loss=-52.3]
# 100%|██████████| 7/7 [00:00<00:00, 15.12it/s, epoch=74, kl_div=0.674, loss=-56.6, recon_loss=-57.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.05it/s, epoch=75, kl_div=1.76, loss=-78.8, recon_loss=-80.6]
# 100%|██████████| 7/7 [00:00<00:00, 15.37it/s, epoch=75, kl_div=10.7, loss=-46.7, recon_loss=-57.4]
# 100%|██████████| 26/26 [00:03<00:00,  8.32it/s, epoch=76, kl_div=1.68, loss=-65.6, recon_loss=-67.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.75it/s, epoch=76, kl_div=1.88, loss=-66.3, recon_loss=-68.2]
# 100%|██████████| 26/26 [00:03<00:00,  8.23it/s, epoch=77, kl_div=9.2, loss=-42.2, recon_loss=-51.4]
# 100%|██████████| 7/7 [00:00<00:00, 15.91it/s, epoch=77, kl_div=1.09, loss=-55.9, recon_loss=-57]
# 100%|██████████| 26/26 [00:03<00:00,  7.97it/s, epoch=78, kl_div=1.1, loss=-52.4, recon_loss=-53.5]
# 100%|██████████| 7/7 [00:00<00:00, 15.84it/s, epoch=78, kl_div=0.519, loss=-63.2, recon_loss=-63.7]
# 100%|██████████| 26/26 [00:03<00:00,  8.29it/s, epoch=79, kl_div=66.2, loss=-7.11, recon_loss=-73.3]
# 100%|██████████| 7/7 [00:00<00:00, 15.30it/s, epoch=79, kl_div=8.52, loss=-45, recon_loss=-53.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.18it/s, epoch=80, kl_div=5.76, loss=-68.7, recon_loss=-74.4]
# 100%|██████████| 7/7 [00:00<00:00, 15.96it/s, epoch=80, kl_div=30.5, loss=-30.9, recon_loss=-61.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.26it/s, epoch=81, kl_div=11, loss=-16.2, recon_loss=-27.2]
# 100%|██████████| 7/7 [00:00<00:00, 16.52it/s, epoch=81, kl_div=36, loss=-14.1, recon_loss=-50.1]
# 100%|██████████| 26/26 [00:03<00:00,  8.11it/s, epoch=82, kl_div=0.6, loss=-42.7, recon_loss=-43.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.25it/s, epoch=82, kl_div=0.664, loss=-59.3, recon_loss=-59.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.29it/s, epoch=83, kl_div=5.54, loss=-53.7, recon_loss=-59.3]
# 100%|██████████| 7/7 [00:00<00:00, 14.72it/s, epoch=83, kl_div=27.6, loss=-33.4, recon_loss=-61]
# 100%|██████████| 26/26 [00:03<00:00,  8.17it/s, epoch=84, kl_div=40.6, loss=8.3, recon_loss=-32.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.99it/s, epoch=84, kl_div=32.8, loss=-22.1, recon_loss=-54.8]
# 100%|██████████| 26/26 [00:03<00:00,  8.46it/s, epoch=85, kl_div=2.55, loss=-62.2, recon_loss=-64.7]
# 100%|██████████| 7/7 [00:00<00:00, 15.59it/s, epoch=85, kl_div=0.564, loss=-70.4, recon_loss=-70.9]
# 100%|██████████| 26/26 [00:03<00:00,  8.09it/s, epoch=86, kl_div=3.99, loss=-36.3, recon_loss=-40.3]
# 100%|██████████| 7/7 [00:00<00:00, 16.19it/s, epoch=86, kl_div=7.04, loss=-46.5, recon_loss=-53.6]
# 100%|██████████| 26/26 [00:03<00:00,  7.91it/s, epoch=87, kl_div=0.817, loss=-81, recon_loss=-81.8]
# 100%|██████████| 7/7 [00:00<00:00, 16.66it/s, epoch=87, kl_div=17.4, loss=-24.2, recon_loss=-41.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.26it/s, epoch=88, kl_div=49.6, loss=-32.1, recon_loss=-81.7]
# 100%|██████████| 7/7 [00:00<00:00, 15.96it/s, epoch=88, kl_div=0.43, loss=-67.1, recon_loss=-67.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.17it/s, epoch=89, kl_div=48.4, loss=-35.4, recon_loss=-83.7]
# 100%|██████████| 7/7 [00:00<00:00, 16.75it/s, epoch=89, kl_div=8.33, loss=-41.7, recon_loss=-50]
# 100%|██████████| 26/26 [00:03<00:00,  8.29it/s, epoch=90, kl_div=2.95, loss=-63.2, recon_loss=-66.2]
# 100%|██████████| 7/7 [00:00<00:00, 15.82it/s, epoch=90, kl_div=4.85, loss=-24.9, recon_loss=-29.7]
# 100%|██████████| 26/26 [00:03<00:00,  8.17it/s, epoch=91, kl_div=6.2, loss=-47.4, recon_loss=-53.6]
# 100%|██████████| 7/7 [00:00<00:00, 16.78it/s, epoch=91, kl_div=8.59, loss=-53.9, recon_loss=-62.5]
# 100%|██████████| 26/26 [00:03<00:00,  8.21it/s, epoch=92, kl_div=10, loss=-67.8, recon_loss=-77.8]
# 100%|██████████| 7/7 [00:00<00:00, 15.04it/s, epoch=92, kl_div=5.04, loss=-58.6, recon_loss=-63.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.19it/s, epoch=93, kl_div=4.25, loss=-80.8, recon_loss=-85.1]
# 100%|██████████| 7/7 [00:00<00:00, 14.89it/s, epoch=93, kl_div=9.31, loss=-63.5, recon_loss=-72.8]
# 100%|██████████| 26/26 [00:03<00:00,  7.88it/s, epoch=94, kl_div=3.18, loss=-77.3, recon_loss=-80.5]
# 100%|██████████| 7/7 [00:00<00:00, 15.73it/s, epoch=94, kl_div=12.4, loss=-41.6, recon_loss=-54]
# 100%|██████████| 26/26 [00:03<00:00,  8.34it/s, epoch=95, kl_div=4.5, loss=-52, recon_loss=-56.5]
# 100%|██████████| 7/7 [00:00<00:00, 16.13it/s, epoch=95, kl_div=4.12, loss=-53.2, recon_loss=-57.3]
# 100%|██████████| 26/26 [00:03<00:00,  8.11it/s, epoch=96, kl_div=15.5, loss=-61.9, recon_loss=-77.5]
# 100%|██████████| 7/7 [00:00<00:00, 16.18it/s, epoch=96, kl_div=0.755, loss=-17.6, recon_loss=-18.4]
# 100%|██████████| 26/26 [00:03<00:00,  8.44it/s, epoch=97, kl_div=5.33, loss=-87.7, recon_loss=-93.1]
# 100%|██████████| 7/7 [00:00<00:00, 16.15it/s, epoch=97, kl_div=1.5, loss=-55.1, recon_loss=-56.6]
# 100%|██████████| 26/26 [00:03<00:00,  8.36it/s, epoch=98, kl_div=41.9, loss=-18.9, recon_loss=-60.7]
# 100%|██████████| 7/7 [00:00<00:00, 15.51it/s, epoch=98, kl_div=3.53, loss=-54.5, recon_loss=-58.1]
# 100%|██████████| 26/26 [00:03<00:00,  8.34it/s, epoch=99, kl_div=0.567, loss=-79.6, recon_loss=-80.2]
# 100%|██████████| 7/7 [00:00<00:00, 16.62it/s, epoch=99, kl_div=4.02, loss=-62.6, recon_loss=-66.6]

# %%
_, ax = plt.subplots(2, 1, figsize=(9, 6))

ax[0].plot(avg_train_neg_log_likes, label="train")
ax[0].plot(avg_val_neg_log_likes, label="val")
ax[0].set_title("Negative Log Likelihood")
ax[0].grid()
ax[0].legend()

ax[1].plot(avg_train_kl_divs, label="train")
ax[1].plot(avg_val_kl_divs, label="val")
ax[1].set_title("KL Divergence")
ax[1].grid()
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
gen_dataloader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1, shuffle=True)

x_data, y_data = next(iter(gen_dataloader))
x_data, y_data = x_data.to(device), y_data.to(device)

factor = 0.3
x_context, y_context, x_target, y_target = split_context_target(x_data, y_data, factor, random=False)

n_samples = 100

mus, logvars, _, _ = model.sample(x_context, y_context, x_data, n_samples)

for i in range(n_samples):
    plt.scatter(x_data.cpu().detach().numpy(), mus[i].cpu().detach().numpy(), marker=".")
    # plt.scatter(
    #     x_data.cpu().detach().numpy(), 
    #     (mus[i] - 2*torch.exp(0.5 * logvars[i])).cpu().detach().numpy(), 
    #     marker=".", 
    #     c="blue",
    #     alpha=0.3,
    # )
    # plt.scatter(
    #     x_data.cpu().detach().numpy(), 
    #     (mus[i] + 2*torch.exp(0.5 * logvars[i])).cpu().detach().numpy(), 
    #     marker=".", 
    #     c="blue",
    #     alpha=0.3,
    # )

plt.scatter(x_context.cpu().detach().numpy(), y_context.cpu().detach().numpy(), marker="o", c="red")

plt.show()

# %%
torch.save(model.state_dict(), "../../models/smooth-durian-5.pt")

# %%
model.load_state_dict(torch.load("../../models/smooth-durian-5.pt"))

from tqdm import tqdm

mus = []

num_samples = 10000

for i, (x_data, y_data) in tqdm(enumerate(gen_dataloader), total=num_samples):

    x_data, y_data = x_data.to(device), y_data.to(device)

    factor = 0.5
    x_context, y_context, _, _ = split_context_target(x_data, y_data, factor, random=False)
    _, mu, _ = model.encode(x_data, y_data)

    mus.append(mu.cpu().detach().numpy())

    if i + 1 == num_samples:
        break
# Out:
#  41%|████      | 4096/10000 [00:12<00:18, 315.13it/s]

# %%
import numpy as np
from sklearn.manifold import TSNE

X = np.array([m[0] for m in mus])
X_embedded = TSNE(n_components=2).fit_transform(X)

plt.scatter(X_embedded[:, 0], X_embedded[:, 1])
plt.show()
