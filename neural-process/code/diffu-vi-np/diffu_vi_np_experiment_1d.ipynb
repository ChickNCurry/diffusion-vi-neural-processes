# %%
import metalearning_benchmarks.line_sine1d_benchmark
import torch
import wandb
from diffu_vi_np import DiffusionNeuralProcess
from diffu_vi_np_train_val import train_and_validate
from diffusion import DDS
from matplotlib import pyplot as plt
from metalearning_benchmarks.line_sine1d_benchmark import LineSine1D
from neural_process import NeuralProcess
from utils import (Config, DataConfig, DataModule, MetaLearningDataset,
                   ModelConfig, TrainValConfig, split_context_target)
from visualize import visualize_batch_1d

# %%
device = None

try:
    import torch_directml
    device = torch_directml.device()
except ModuleNotFoundError:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
print(device)
# Out:
# privateuseone:0

# %%
data_config = DataConfig(
    benchmark="LineSine1D",
    n_task=4096,
    n_datapoints_per_task=64,
    output_noise=0.1,
    seed_task=1237, 
    seed_x=123, 
    seed_noise=1237
)

model_config = ModelConfig(
    x_dim=1,
    y_dim=1,
    r_dim=16,
    z_dim=2,
    h_dim=64,
    num_layers_det_enc=6,
    num_layers_lat_enc=3,
    num_layers_dec=6,
    non_linearity="SiLU",
    is_attentive=False,
    has_parallel_paths=False
)

train_val_config = TrainValConfig(
    batch_size=128,
    num_epochs=400,
    learning_rate=3e-5,
    split=(0.8, 0.2)
)

config = Config(
    data_config=data_config,
    model_config=model_config,
    train_val_config=train_val_config
)

# %%
benchmark = getattr(metalearning_benchmarks.line_sine1d_benchmark, config.data_config.benchmark)(
    n_task=config.data_config.n_task,
    n_datapoints_per_task=config.data_config.n_datapoints_per_task,
    output_noise=config.data_config.output_noise,
    seed_task=config.data_config.seed_task, 
    seed_x=config.data_config.seed_x, 
    seed_noise=config.data_config.seed_noise,
)

dataset = MetaLearningDataset(benchmark)

data_module = DataModule(
    batch_size=config.train_val_config.batch_size,
    dataset_and_split=(dataset, config.train_val_config.split),
    num_workers=15
)
# Out:
# Generating tasks: 100%|██████████| 4096/4096 [00:00<00:00, 275902.06it/s]

# %%
# visualize_batch_1d(batch=next(iter(data_module.train_dataloader())))

# %%
np_model = NeuralProcess(**config.model_config.asdict()).to(device)
diffu_model = DDS(device=device, num_steps=16, z_dim=2, h_dim=64, beta_start=0.0001, beta_end=0.02, std_0=torch.tensor(1.0)).to(device)
diffu_vi_np_model = DiffusionNeuralProcess(np_model, diffu_model).to(device)

optimizer = torch.optim.Adam(diffu_vi_np_model.parameters(), lr=config.train_val_config.learning_rate)

# %%
wandb_logging = True
if wandb_logging:
    wandb.init(project="diffu-vi-np", config=config.asdict())
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: max-burzer (max-burzer-karlsruhe-institute-of-technology). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.0
# Run data is saved locally in <code>/home/chickencurry/diffusion-vi-neural-processes/neural-process/code/diffu-vi-np/wandb/run-20240926_161034-hi9dr7qv</code>
# Syncing run <strong><a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np/runs/hi9dr7qv' target="_blank">dazzling-frog-16</a></strong> to <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np</a>
#  View run at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np/runs/hi9dr7qv' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np/runs/hi9dr7qv</a>

# %%
avg_train_neg_log_likes = []
avg_train_kl_divs = []
avg_train_diffu_loss = []

avg_val_neg_log_likes = []
avg_val_kl_divs = []
avg_val_diffu_loss = []

# %%
losses = train_and_validate(
    diffu_vi_np_model=diffu_vi_np_model,
    data_module=data_module,
    num_epochs=config.train_val_config.num_epochs,
    device=device,
    optimizer=optimizer,
    wandb_logging=wandb_logging,
)

avg_train_neg_log_likes.extend(losses[0])
avg_train_kl_divs.extend(losses[1])
avg_train_diffu_loss.extend(losses[2])

avg_val_neg_log_likes.extend(losses[3])
avg_val_kl_divs.extend(losses[4])
avg_val_diffu_loss.extend(losses[5])
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]/home/chickencurry/miniconda3/envs/directml/lib/python3.11/site-packages/torch/optim/adam.py:522: UserWarning: The operator 'aten::_foreach_lerp_.Scalar' is not currently supported on the DML backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /__w/1/s/pytorch-directml-plugin/torch_directml/csrc/dml/dml_cpu_fallback.cpp:15.)
#   torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
# 100%|██████████| 26/26 [00:10<00:00,  2.45it/s, diffu_loss=-5.15e+3, epoch=0, kl_div=1.06e-5, loss=6.22e+3, recon_loss=1.07e+3]
# 100%|██████████| 7/7 [00:01<00:00,  3.78it/s, diffu_loss=-4.27e+3, epoch=0, kl_div=5.44e-5, loss=5.32e+3, recon_loss=1.05e+3]
# 100%|██████████| 26/26 [00:09<00:00,  2.71it/s, diffu_loss=-4.54e+3, epoch=1, kl_div=0.000186, loss=5.68e+3, recon_loss=1.14e+3]
# 100%|██████████| 7/7 [00:01<00:00,  3.73it/s, diffu_loss=-5.56e+3, epoch=1, kl_div=0.00249, loss=6.6e+3, recon_loss=1.04e+3]
# 100%|██████████| 26/26 [00:09<00:00,  2.70it/s, diffu_loss=-4.29e+3, epoch=2, kl_div=0.000502, loss=5.46e+3, recon_loss=1.18e+3]
# 100%|██████████| 7/7 [00:01<00:00,  3.79it/s, diffu_loss=-3.3e+3, epoch=2, kl_div=0.00172, loss=4.33e+3, recon_loss=1.03e+3]
# 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, diffu_loss=-3.83e+3, epoch=3, kl_div=0.0118, loss=4.8e+3, recon_loss=969]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-4.63e+3, epoch=3, kl_div=0.00014, loss=5.65e+3, recon_loss=1.01e+3]
# 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, diffu_loss=-3.6e+3, epoch=4, kl_div=2.82e-5, loss=4.72e+3, recon_loss=1.12e+3]
# 100%|██████████| 7/7 [00:01<00:00,  3.50it/s, diffu_loss=-3.43e+3, epoch=4, kl_div=0.00138, loss=4.43e+3, recon_loss=1e+3]
# 100%|██████████| 26/26 [00:10<00:00,  2.60it/s, diffu_loss=-4.72e+3, epoch=5, kl_div=0.000421, loss=5.91e+3, recon_loss=1.19e+3]
# 100%|██████████| 7/7 [00:01<00:00,  3.57it/s, diffu_loss=-3.6e+3, epoch=5, kl_div=4.25e-5, loss=4.59e+3, recon_loss=988]
# 100%|██████████| 26/26 [00:10<00:00,  2.39it/s, diffu_loss=-3.77e+3, epoch=6, kl_div=0.00355, loss=4.67e+3, recon_loss=898]
# 100%|██████████| 7/7 [00:02<00:00,  3.28it/s, diffu_loss=-3.72e+3, epoch=6, kl_div=2.38e-5, loss=4.69e+3, recon_loss=968]
# 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, diffu_loss=-2.95e+3, epoch=7, kl_div=0.00032, loss=3.83e+3, recon_loss=878]
# 100%|██████████| 7/7 [00:01<00:00,  3.66it/s, diffu_loss=-2.58e+3, epoch=7, kl_div=0.0011, loss=3.51e+3, recon_loss=930]
# 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, diffu_loss=-2.91e+3, epoch=8, kl_div=0.0129, loss=3.9e+3, recon_loss=995]
# 100%|██████████| 7/7 [00:01<00:00,  3.73it/s, diffu_loss=-2.47e+3, epoch=8, kl_div=0.00197, loss=3.31e+3, recon_loss=844]
# 100%|██████████| 26/26 [00:09<00:00,  2.70it/s, diffu_loss=-2.36e+3, epoch=9, kl_div=0.0035, loss=3.22e+3, recon_loss=862]
# 100%|██████████| 7/7 [00:01<00:00,  3.71it/s, diffu_loss=-2.91e+3, epoch=9, kl_div=0.0137, loss=3.62e+3, recon_loss=706]
# 100%|██████████| 26/26 [00:09<00:00,  2.71it/s, diffu_loss=-2.36e+3, epoch=10, kl_div=0.00185, loss=2.9e+3, recon_loss=548]
# 100%|██████████| 7/7 [00:01<00:00,  3.73it/s, diffu_loss=-2.5e+3, epoch=10, kl_div=0.0107, loss=3.06e+3, recon_loss=561]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=-1.71e+3, epoch=11, kl_div=0.0139, loss=2.21e+3, recon_loss=504]
# 100%|██████████| 7/7 [00:01<00:00,  3.76it/s, diffu_loss=-1.96e+3, epoch=11, kl_div=0.0322, loss=2.39e+3, recon_loss=438]
# 100%|██████████| 26/26 [00:09<00:00,  2.75it/s, diffu_loss=-1.44e+3, epoch=12, kl_div=0.0166, loss=1.78e+3, recon_loss=333]
# 100%|██████████| 7/7 [00:01<00:00,  3.72it/s, diffu_loss=-1.84e+3, epoch=12, kl_div=0.0151, loss=2.19e+3, recon_loss=345]
# 100%|██████████| 26/26 [00:09<00:00,  2.75it/s, diffu_loss=-1.5e+3, epoch=13, kl_div=0.0288, loss=1.76e+3, recon_loss=261]
# 100%|██████████| 7/7 [00:01<00:00,  3.74it/s, diffu_loss=-1.76e+3, epoch=13, kl_div=0.045, loss=2.05e+3, recon_loss=287]
# 100%|██████████| 26/26 [00:09<00:00,  2.69it/s, diffu_loss=-1.4e+3, epoch=14, kl_div=0.165, loss=1.65e+3, recon_loss=258]
# 100%|██████████| 7/7 [00:01<00:00,  3.64it/s, diffu_loss=-1.21e+3, epoch=14, kl_div=0.0529, loss=1.46e+3, recon_loss=252]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=-1.06e+3, epoch=15, kl_div=0.0857, loss=1.33e+3, recon_loss=268]
# 100%|██████████| 7/7 [00:01<00:00,  3.69it/s, diffu_loss=-1.02e+3, epoch=15, kl_div=0.000363, loss=1.25e+3, recon_loss=232]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=-865, epoch=16, kl_div=0.0101, loss=1.11e+3, recon_loss=241]
# 100%|██████████| 7/7 [00:01<00:00,  3.67it/s, diffu_loss=-1.11e+3, epoch=16, kl_div=0.0768, loss=1.33e+3, recon_loss=219]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=-921, epoch=17, kl_div=0.0177, loss=1.14e+3, recon_loss=220]
# 100%|██████████| 7/7 [00:01<00:00,  3.74it/s, diffu_loss=-645, epoch=17, kl_div=0.0256, loss=855, recon_loss=210]
# 100%|██████████| 26/26 [00:09<00:00,  2.71it/s, diffu_loss=-602, epoch=18, kl_div=0.0707, loss=818, recon_loss=215]
# 100%|██████████| 7/7 [00:01<00:00,  3.75it/s, diffu_loss=-553, epoch=18, kl_div=0.0139, loss=758, recon_loss=204]
# 100%|██████████| 26/26 [00:09<00:00,  2.71it/s, diffu_loss=-534, epoch=19, kl_div=0.000771, loss=741, recon_loss=207]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-661, epoch=19, kl_div=0.122, loss=861, recon_loss=200]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=-522, epoch=20, kl_div=0.0303, loss=725, recon_loss=203]
# 100%|██████████| 7/7 [00:01<00:00,  3.70it/s, diffu_loss=-384, epoch=20, kl_div=0.035, loss=581, recon_loss=197]
# 100%|██████████| 26/26 [00:09<00:00,  2.69it/s, diffu_loss=-546, epoch=21, kl_div=0.0775, loss=755, recon_loss=208]
# 100%|██████████| 7/7 [00:01<00:00,  3.70it/s, diffu_loss=-442, epoch=21, kl_div=0.36, loss=637, recon_loss=195]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=-462, epoch=22, kl_div=0.0226, loss=650, recon_loss=188]
# 100%|██████████| 7/7 [00:01<00:00,  3.66it/s, diffu_loss=-284, epoch=22, kl_div=0.034, loss=477, recon_loss=193]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=-304, epoch=23, kl_div=0.0221, loss=507, recon_loss=202]
# 100%|██████████| 7/7 [00:01<00:00,  3.60it/s, diffu_loss=-328, epoch=23, kl_div=0.0243, loss=519, recon_loss=191]
# 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, diffu_loss=-274, epoch=24, kl_div=0.0947, loss=476, recon_loss=203]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-274, epoch=24, kl_div=0.0236, loss=464, recon_loss=190]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=-229, epoch=25, kl_div=0.057, loss=428, recon_loss=198]
# 100%|██████████| 7/7 [00:01<00:00,  3.61it/s, diffu_loss=-335, epoch=25, kl_div=0.00343, loss=524, recon_loss=189]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=-301, epoch=26, kl_div=0.444, loss=500, recon_loss=198]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-267, epoch=26, kl_div=0.0467, loss=456, recon_loss=189]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=-259, epoch=27, kl_div=0.0625, loss=452, recon_loss=194]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-267, epoch=27, kl_div=0.025, loss=455, recon_loss=188]
# 100%|██████████| 26/26 [00:09<00:00,  2.70it/s, diffu_loss=-183, epoch=28, kl_div=0.0169, loss=381, recon_loss=198]
# 100%|██████████| 7/7 [00:01<00:00,  3.63it/s, diffu_loss=-253, epoch=28, kl_div=0.0469, loss=441, recon_loss=188]
# 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, diffu_loss=-229, epoch=29, kl_div=0.00673, loss=420, recon_loss=192]
# 100%|██████████| 7/7 [00:01<00:00,  3.55it/s, diffu_loss=-233, epoch=29, kl_div=2.41e+3, loss=2.83e+3, recon_loss=187]
# 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, diffu_loss=-269, epoch=30, kl_div=1.42, loss=469, recon_loss=198]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-205, epoch=30, kl_div=0.0272, loss=392, recon_loss=187]
# 100%|██████████| 26/26 [00:09<00:00,  2.69it/s, diffu_loss=-200, epoch=31, kl_div=0.0168, loss=392, recon_loss=193]
# 100%|██████████| 7/7 [00:01<00:00,  3.69it/s, diffu_loss=-234, epoch=31, kl_div=0.129, loss=420, recon_loss=186]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=-87.2, epoch=32, kl_div=0.0587, loss=285, recon_loss=198]
# 100%|██████████| 7/7 [00:01<00:00,  3.54it/s, diffu_loss=-148, epoch=32, kl_div=0.032, loss=334, recon_loss=186]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=-116, epoch=33, kl_div=0.172, loss=303, recon_loss=188]
# 100%|██████████| 7/7 [00:01<00:00,  3.59it/s, diffu_loss=-158, epoch=33, kl_div=0.0168, loss=344, recon_loss=186]
# 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, diffu_loss=-174, epoch=34, kl_div=0.228, loss=362, recon_loss=188]
# 100%|██████████| 7/7 [00:01<00:00,  3.69it/s, diffu_loss=-195, epoch=34, kl_div=0.00329, loss=380, recon_loss=185]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=-107, epoch=35, kl_div=0.0021, loss=298, recon_loss=191]
# 100%|██████████| 7/7 [00:01<00:00,  3.73it/s, diffu_loss=-152, epoch=35, kl_div=0.0392, loss=337, recon_loss=185]
# 100%|██████████| 26/26 [00:09<00:00,  2.71it/s, diffu_loss=-49.9, epoch=36, kl_div=0.0618, loss=243, recon_loss=193]
# 100%|██████████| 7/7 [00:01<00:00,  3.68it/s, diffu_loss=-65.1, epoch=36, kl_div=0.0367, loss=250, recon_loss=185]
# 100%|██████████| 26/26 [00:09<00:00,  2.70it/s, diffu_loss=12.3, epoch=37, kl_div=0.0932, loss=185, recon_loss=197]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-73.8, epoch=37, kl_div=0.204, loss=258, recon_loss=184]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=16.6, epoch=38, kl_div=0.452, loss=168, recon_loss=184]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=-21.1, epoch=38, kl_div=0.0665, loss=205, recon_loss=184]
# 100%|██████████| 26/26 [00:09<00:00,  2.76it/s, diffu_loss=88.6, epoch=39, kl_div=0.131, loss=100, recon_loss=189]
# 100%|██████████| 7/7 [00:01<00:00,  3.53it/s, diffu_loss=101, epoch=39, kl_div=0.17, loss=82.5, recon_loss=184]
# 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, diffu_loss=45.4, epoch=40, kl_div=92.9, loss=227, recon_loss=179]
# 100%|██████████| 7/7 [00:02<00:00,  3.32it/s, diffu_loss=118, epoch=40, kl_div=0.199, loss=65.5, recon_loss=183]
# 100%|██████████| 26/26 [00:10<00:00,  2.46it/s, diffu_loss=259, epoch=41, kl_div=0.0378, loss=-65.8, recon_loss=193]
# 100%|██████████| 7/7 [00:02<00:00,  3.13it/s, diffu_loss=247, epoch=41, kl_div=0.195, loss=-63.4, recon_loss=183]
# 100%|██████████| 26/26 [00:09<00:00,  2.63it/s, diffu_loss=277, epoch=42, kl_div=0.519, loss=-87.5, recon_loss=189]
# 100%|██████████| 7/7 [00:02<00:00,  3.22it/s, diffu_loss=267, epoch=42, kl_div=0.00684, loss=-84.7, recon_loss=183]
# 100%|██████████| 26/26 [00:09<00:00,  2.62it/s, diffu_loss=388, epoch=43, kl_div=0.0148, loss=-203, recon_loss=184]
# 100%|██████████| 7/7 [00:01<00:00,  3.53it/s, diffu_loss=508, epoch=43, kl_div=0.0715, loss=-325, recon_loss=182]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=571, epoch=44, kl_div=0.656, loss=-384, recon_loss=186]
# 100%|██████████| 7/7 [00:02<00:00,  3.38it/s, diffu_loss=660, epoch=44, kl_div=0.00117, loss=-478, recon_loss=182]
# 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, diffu_loss=836, epoch=45, kl_div=0.24, loss=-654, recon_loss=182]
# 100%|██████████| 7/7 [00:01<00:00,  3.65it/s, diffu_loss=701, epoch=45, kl_div=0.0734, loss=-519, recon_loss=182]
# 100%|██████████| 26/26 [00:10<00:00,  2.46it/s, diffu_loss=1.08e+3, epoch=46, kl_div=2.76, loss=-883, recon_loss=191]
# 100%|██████████| 7/7 [00:02<00:00,  3.05it/s, diffu_loss=993, epoch=46, kl_div=0.104, loss=-811, recon_loss=181]
# 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, diffu_loss=1.43e+3, epoch=47, kl_div=6.68, loss=-1.22e+3, recon_loss=196]
# 100%|██████████| 7/7 [00:02<00:00,  3.27it/s, diffu_loss=1.39e+3, epoch=47, kl_div=0.0487, loss=-1.21e+3, recon_loss=181]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=1.85e+3, epoch=48, kl_div=10.1, loss=-1.65e+3, recon_loss=190]
# 100%|██████████| 7/7 [00:01<00:00,  3.60it/s, diffu_loss=1.85e+3, epoch=48, kl_div=0.0269, loss=-1.67e+3, recon_loss=181]
# 100%|██████████| 26/26 [00:09<00:00,  2.65it/s, diffu_loss=2.37e+3, epoch=49, kl_div=0.24, loss=-2.19e+3, recon_loss=182]
# 100%|██████████| 7/7 [00:01<00:00,  3.62it/s, diffu_loss=2.13e+3, epoch=49, kl_div=0.334, loss=-1.95e+3, recon_loss=180]
# 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, diffu_loss=3.15e+3, epoch=50, kl_div=0.221, loss=-2.96e+3, recon_loss=186]
# 100%|██████████| 7/7 [00:01<00:00,  3.58it/s, diffu_loss=3.19e+3, epoch=50, kl_div=0.0395, loss=-3.02e+3, recon_loss=180]
# 100%|██████████| 26/26 [00:10<00:00,  2.48it/s, diffu_loss=4.06e+3, epoch=51, kl_div=0.0643, loss=-3.87e+3, recon_loss=191]
# 100%|██████████| 7/7 [00:01<00:00,  3.50it/s, diffu_loss=3.96e+3, epoch=51, kl_div=0.179, loss=-3.79e+3, recon_loss=179]
# 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, diffu_loss=5.26e+3, epoch=52, kl_div=0.39, loss=-5.08e+3, recon_loss=184]
# 100%|██████████| 7/7 [00:01<00:00,  3.51it/s, diffu_loss=5.38e+3, epoch=52, kl_div=4.37, loss=-5.2e+3, recon_loss=179]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=6.72e+3, epoch=53, kl_div=0.884, loss=-6.53e+3, recon_loss=186]
# 100%|██████████| 7/7 [00:01<00:00,  3.59it/s, diffu_loss=6.4e+3, epoch=53, kl_div=0.485, loss=-6.22e+3, recon_loss=178]
# 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, diffu_loss=8.49e+3, epoch=54, kl_div=0.197, loss=-8.3e+3, recon_loss=183]
# 100%|██████████| 7/7 [00:01<00:00,  3.60it/s, diffu_loss=8.27e+3, epoch=54, kl_div=0.56, loss=-8.09e+3, recon_loss=178]
# 100%|██████████| 26/26 [00:09<00:00,  2.71it/s, diffu_loss=1.11e+4, epoch=55, kl_div=0.0935, loss=-1.09e+4, recon_loss=177]
# 100%|██████████| 7/7 [00:01<00:00,  3.56it/s, diffu_loss=1.1e+4, epoch=55, kl_div=0.0439, loss=-1.08e+4, recon_loss=177]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=1.48e+4, epoch=56, kl_div=0.361, loss=-1.46e+4, recon_loss=195]
# 100%|██████████| 7/7 [00:01<00:00,  3.68it/s, diffu_loss=1.43e+4, epoch=56, kl_div=7.26e+3, loss=-6.89e+3, recon_loss=177]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=1.91e+4, epoch=57, kl_div=0.257, loss=-1.89e+4, recon_loss=184]
# 100%|██████████| 7/7 [00:01<00:00,  3.66it/s, diffu_loss=1.89e+4, epoch=57, kl_div=0.337, loss=-1.87e+4, recon_loss=176]
# 100%|██████████| 26/26 [00:09<00:00,  2.69it/s, diffu_loss=2.54e+4, epoch=58, kl_div=1.61, loss=-2.52e+4, recon_loss=179]
# 100%|██████████| 7/7 [00:01<00:00,  3.54it/s, diffu_loss=2.51e+4, epoch=58, kl_div=7.78, loss=-2.49e+4, recon_loss=176]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=3.36e+4, epoch=59, kl_div=0.508, loss=-3.35e+4, recon_loss=174]
# 100%|██████████| 7/7 [00:01<00:00,  3.57it/s, diffu_loss=3.29e+4, epoch=59, kl_div=3.94, loss=-3.27e+4, recon_loss=175]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=4.33e+4, epoch=60, kl_div=1.94, loss=-4.31e+4, recon_loss=187]
# 100%|██████████| 7/7 [00:01<00:00,  3.56it/s, diffu_loss=4.24e+4, epoch=60, kl_div=1.44, loss=-4.22e+4, recon_loss=175]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=5.29e+4, epoch=61, kl_div=0.92, loss=-5.28e+4, recon_loss=175]
# 100%|██████████| 7/7 [00:01<00:00,  3.60it/s, diffu_loss=5.12e+4, epoch=61, kl_div=34.4, loss=-5.1e+4, recon_loss=174]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=6.41e+4, epoch=62, kl_div=0.0502, loss=-6.39e+4, recon_loss=176]
# 100%|██████████| 7/7 [00:01<00:00,  3.62it/s, diffu_loss=6.29e+4, epoch=62, kl_div=2.03, loss=-6.27e+4, recon_loss=174]
# 100%|██████████| 26/26 [00:09<00:00,  2.72it/s, diffu_loss=7.73e+4, epoch=63, kl_div=45, loss=-7.7e+4, recon_loss=182]
# 100%|██████████| 7/7 [00:01<00:00,  3.56it/s, diffu_loss=7.53e+4, epoch=63, kl_div=2.28, loss=-7.52e+4, recon_loss=173]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=90333.5, epoch=64, kl_div=3.34, loss=-9.02e+4, recon_loss=176]
# 100%|██████████| 7/7 [00:01<00:00,  3.52it/s, diffu_loss=8.96e+4, epoch=64, kl_div=22.6, loss=-8.94e+4, recon_loss=173]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=1.09e+5, epoch=65, kl_div=5.89, loss=-1.09e+5, recon_loss=183]
# 100%|██████████| 7/7 [00:02<00:00,  3.42it/s, diffu_loss=1.08e+5, epoch=65, kl_div=5.62, loss=-1.08e+5, recon_loss=173]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=1.25e+5, epoch=66, kl_div=24.8, loss=-1.25e+5, recon_loss=174]
# 100%|██████████| 7/7 [00:01<00:00,  3.58it/s, diffu_loss=1.22e+5, epoch=66, kl_div=13.6, loss=-1.22e+5, recon_loss=173]
# 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, diffu_loss=1.43e+5, epoch=67, kl_div=8.06e+3, loss=-1.35e+5, recon_loss=174]
# 100%|██████████| 7/7 [00:01<00:00,  3.59it/s, diffu_loss=1.41e+5, epoch=67, kl_div=8.86, loss=-1.41e+5, recon_loss=172]
# 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, diffu_loss=1.67e+5, epoch=68, kl_div=1.88, loss=-1.67e+5, recon_loss=171]
# 100%|██████████| 7/7 [00:01<00:00,  3.55it/s, diffu_loss=1.66e+5, epoch=68, kl_div=4.55, loss=-1.66e+5, recon_loss=172]
# 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, diffu_loss=2.03e+5, epoch=69, kl_div=32.1, loss=-2.03e+5, recon_loss=173]
# 100%|██████████| 7/7 [00:01<00:00,  3.59it/s, diffu_loss=1.98e+5, epoch=69, kl_div=100, loss=-1.97e+5, recon_loss=171]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=2.51e+5, epoch=70, kl_div=2.97, loss=-2.51e+5, recon_loss=169]
# 100%|██████████| 7/7 [00:01<00:00,  3.60it/s, diffu_loss=2.43e+5, epoch=70, kl_div=121, loss=-2.43e+5, recon_loss=171]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=3.01e+5, epoch=71, kl_div=155, loss=-3e+5, recon_loss=169]
# 100%|██████████| 7/7 [00:01<00:00,  3.51it/s, diffu_loss=2.96e+5, epoch=71, kl_div=111, loss=-2.96e+5, recon_loss=171]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=3.76e+5, epoch=72, kl_div=495, loss=-3.76e+5, recon_loss=174]
# 100%|██████████| 7/7 [00:02<00:00,  3.50it/s, diffu_loss=3.69e+5, epoch=72, kl_div=33.9, loss=-3.69e+5, recon_loss=171]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=5.04e+5, epoch=73, kl_div=2.73, loss=-5.04e+5, recon_loss=168]
# 100%|██████████| 7/7 [00:01<00:00,  3.61it/s, diffu_loss=4.84e+5, epoch=73, kl_div=32.5, loss=-4.84e+5, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.70it/s, diffu_loss=6.69e+5, epoch=74, kl_div=4.43e+4, loss=-6.25e+5, recon_loss=175]
# 100%|██████████| 7/7 [00:01<00:00,  3.54it/s, diffu_loss=6.58e+5, epoch=74, kl_div=2.08, loss=-6.57e+5, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, diffu_loss=9.55e+5, epoch=75, kl_div=78.8, loss=-9.54e+5, recon_loss=171]
# 100%|██████████| 7/7 [00:01<00:00,  3.59it/s, diffu_loss=9.21e+5, epoch=75, kl_div=135, loss=-9.21e+5, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=1.47e+6, epoch=76, kl_div=2.03e+3, loss=-1.46e+6, recon_loss=168]
# 100%|██████████| 7/7 [00:01<00:00,  3.58it/s, diffu_loss=1.43e+6, epoch=76, kl_div=863, loss=-1.43e+6, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.63it/s, diffu_loss=2.17e+6, epoch=77, kl_div=4.63e+3, loss=-2.17e+6, recon_loss=173]
# 100%|██████████| 7/7 [00:01<00:00,  3.61it/s, diffu_loss=2.06e+6, epoch=77, kl_div=67.4, loss=-2.06e+6, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.69it/s, diffu_loss=2.94e+6, epoch=78, kl_div=356, loss=-2.94e+6, recon_loss=168]
# 100%|██████████| 7/7 [00:01<00:00,  3.63it/s, diffu_loss=2.85e+6, epoch=78, kl_div=91.2, loss=-2.85e+6, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.69it/s, diffu_loss=4.27e+6, epoch=79, kl_div=4.83, loss=-4.27e+6, recon_loss=179]
# 100%|██████████| 7/7 [00:01<00:00,  3.57it/s, diffu_loss=4.02e+6, epoch=79, kl_div=292, loss=-4.02e+6, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.66it/s, diffu_loss=5.9e+6, epoch=80, kl_div=3.73e+3, loss=-5.9e+6, recon_loss=162]
# 100%|██████████| 7/7 [00:01<00:00,  3.60it/s, diffu_loss=5.92e+6, epoch=80, kl_div=264, loss=-5.92e+6, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.68it/s, diffu_loss=8.74e+6, epoch=81, kl_div=2.13e+3, loss=-8.74e+6, recon_loss=168]
# 100%|██████████| 7/7 [00:01<00:00,  3.56it/s, diffu_loss=8.62e+6, epoch=81, kl_div=189, loss=-8.62e+6, recon_loss=170]
# 100%|██████████| 26/26 [00:09<00:00,  2.70it/s, diffu_loss=1.18e+7, epoch=82, kl_div=81.6, loss=-1.18e+7, recon_loss=170]
# 100%|██████████| 7/7 [00:01<00:00,  3.54it/s, diffu_loss=1.16e+7, epoch=82, kl_div=1.8e+3, loss=-1.16e+7, recon_loss=169]
# 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, diffu_loss=1.71e+7, epoch=83, kl_div=485, loss=-1.71e+7, recon_loss=172]
# 100%|██████████| 7/7 [00:01<00:00,  3.64it/s, diffu_loss=1.66e+7, epoch=83, kl_div=375, loss=-1.66e+7, recon_loss=169]
# 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, diffu_loss=2.42e+7, epoch=84, kl_div=204, loss=-2.42e+7, recon_loss=171]
# 100%|██████████| 7/7 [00:01<00:00,  3.71it/s, diffu_loss=2.46e+7, epoch=84, kl_div=8.96e+4, loss=-2.45e+7, recon_loss=169]
# 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, diffu_loss=3.92e+7, epoch=85, kl_div=1.11e+5, loss=-3.9e+7, recon_loss=173]
# 100%|██████████| 7/7 [00:02<00:00,  3.10it/s, diffu_loss=3.88e+7, epoch=85, kl_div=1.75e+3, loss=-3.88e+7, recon_loss=170]
# 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, diffu_loss=6.43e+7, epoch=86, kl_div=114, loss=-6.43e+7, recon_loss=172]
# 100%|██████████| 7/7 [00:02<00:00,  3.40it/s, diffu_loss=6.24e+7, epoch=86, kl_div=875, loss=-6.24e+7, recon_loss=170]
# 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, diffu_loss=1.09e+8, epoch=87, kl_div=581, loss=-1.09e+8, recon_loss=166]
# 100%|██████████| 7/7 [00:01<00:00,  3.57it/s, diffu_loss=1.05e+8, epoch=87, kl_div=1.02e+4, loss=-1.05e+8, recon_loss=169]
# 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, diffu_loss=1.94e+8, epoch=88, kl_div=1.17e+6, loss=-1.92e+8, recon_loss=169]
# 100%|██████████| 7/7 [00:02<00:00,  3.21it/s, diffu_loss=1.84e+8, epoch=88, kl_div=1.12e+4, loss=-1.84e+8, recon_loss=169]
# 100%|██████████| 26/26 [00:10<00:00,  2.52it/s, diffu_loss=3.11e+8, epoch=89, kl_div=9.1e+4, loss=-3.1e+8, recon_loss=169]
# 100%|██████████| 7/7 [00:01<00:00,  3.56it/s, diffu_loss=2.92e+8, epoch=89, kl_div=2.53e+5, loss=-2.92e+8, recon_loss=169]
# 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, diffu_loss=5.16e+8, epoch=90, kl_div=2.37e+4, loss=-5.16e+8, recon_loss=171]
#  86%|████████▌ | 6/7 [00:02<00:00,  2.98it/s, diffu_loss=5.29e+8, epoch=90, kl_div=3.32e+3, loss=-5.29e+8, recon_loss=171]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 losses = train_and_validate(
#       2     diffu_vi_np_model=diffu_vi_np_model,
#       3     data_module=data_module,
#       4     num_epochs=config.train_val_config.num_epochs,
#       5     device=device,
#       6     optimizer=optimizer,
#       7     wandb_logging=wandb_logging,
#       8 )
#      10 avg_train_neg_log_likes.extend(losses[0])
#      11 avg_train_kl_divs.extend(losses[1])
#
# File ~/diffusion-vi-neural-processes/neural-process/code/diffu-vi-np/diffu_vi_np_train_val.py:102, in train_and_validate(diffu_vi_np_model, device, data_module, optimizer, num_epochs, wandb_logging, preprocessing)
#      98 loop = tqdm(dataloader, total=len(dataloader))
#     100 for batch in loop:
# --> 102     loss, neg_log_like, kl_div, diffu_loss = step(
#     103         diffu_vi_np_model, device, batch, preprocessing
#     104     )
#     106     val_neg_log_likes.append(neg_log_like.item())
#     107     val_kl_divs.append(kl_div.item())
#
# File ~/diffusion-vi-neural-processes/neural-process/code/diffu-vi-np/diffu_vi_np_train_val.py:186, in step(diffu_vi_np_model, device, batch, preprocessing)
#     183 for t in range(1, diffu_vi_np_model.diffu_model.num_steps):
#     184     f_t = Normal(z_t_mu_list[t - 1], z_t_std_list[t - 1]).log_prob(z_t_list[t]).mean(dim=0).sum()  # type: ignore
# --> 186     _, b_t_mu, b_t_std = diffu_vi_np_model.diffu_model.backward_transition(
#     187         z_t_list[t], torch.tensor([t]).to(device)
#     188     )
#     190     b_t = Normal(b_t_mu, b_t_std).log_prob(z_t_list[t - 1]).mean(dim=0).sum()  # type: ignore
#     192     f_t_list.append(f_t)
#
# File ~/diffusion-vi-neural-processes/neural-process/code/diffu-vi-np/diffusion.py:64, in DiffusionVariant.backward_transition(self, z, t)
#      61 z_mean = self.backward_mean(z, t)
#      62 # (batch_size, z_dim)
# ---> 64 z_var = self.backward_var(t)
#      65 # (1)
#      67 z_prev = self.reparameterize(z_mean, z_var)
#
# File ~/diffusion-vi-neural-processes/neural-process/code/diffu-vi-np/diffusion.py:153, in DDS.backward_var(self, t)
#     150 beta_t = self.betas[t.int()]
#     151 # (1)
# --> 153 z_var = beta_t * torch.pow(self.std_0, 2) * self.delta_t
#     154 # (1)
#     156 return z_var
#
# KeyboardInterrupt:

# %%
_, ax = plt.subplots(1, 2, figsize=(12, 3))

ax[0].plot(avg_train_neg_log_likes, label="train")
ax[0].plot(avg_val_neg_log_likes, label="val")
ax[0].set_title("Negative Log Likelihood")
ax[0].grid()
ax[0].legend()

ax[1].plot(avg_train_kl_divs, label="train")
ax[1].plot(avg_val_kl_divs, label="val")
ax[1].set_title("KL Divergence")
ax[1].grid()
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
gen_dataloader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1, shuffle=True)
x_data, y_data = next(iter(gen_dataloader))
x_data, y_data = x_data.to(device), y_data.to(device)

context_len = 3 # x_data.shape[1] - 1
x_context, y_context, _, _ = split_context_target(x_data, y_data, context_len=context_len, random=False)

n_samples = 1024

model.eval()
_, y_mu, _, z, _, _ = model.sample(x_context, y_context, x_data, n_samples)

x_data = x_data.cpu().detach().numpy()
y_data = y_data.cpu().detach().numpy()
x_context = x_context.cpu().detach().numpy()
y_context = y_context.cpu().detach().numpy()
y_mu = y_mu.cpu().detach().numpy()
z = z.cpu().detach().numpy()

_, ax  = plt.subplots(1, 2, figsize=(12, 3), gridspec_kw={'width_ratios': [3, 1]})

for i in range(n_samples):
    ax[0].scatter(x_data, y_mu[i], marker=".", alpha=0.2)

ax[0].scatter(x_data, y_data, marker="o", c="black")
ax[0].scatter(x_context, y_context, marker="o", c="red")

ax[1].hist2d(z[:, 0, 0], z[:, 0, 1], bins=20, cmap="inferno")

plt.tight_layout()
plt.show()

# %%
# model.load_state_dict(torch.load("../../models/icy-salad-8.pt"))
gen_dataloader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1, shuffle=True)

x_data, y_data = next(iter(gen_dataloader))
x_data, y_data = x_data.to(device), y_data.to(device)

context_len = 1
x_context, y_context, x_target, y_target = split_context_target(x_data, y_data, context_len=context_len, random=True)

n_samples = 1

model.eval()
y, y_mu, y_std = model(x_context, y_context, x_data)

plt.figure(figsize=(9, 3))

for i in range(n_samples):
    plt.scatter(x_data.cpu().detach().numpy(), y_mu[i].cpu().detach().numpy(), marker=".")
    plt.scatter(
        x_data.cpu().detach().numpy(), 
        (y_mu[i] - 2 * y_std).cpu().detach().numpy(), 
        marker=".", 
        c="blue",
        alpha=0.3,
    )
    plt.scatter(
        x_data.cpu().detach().numpy(), 
        (y_mu[i] + 2 * y_std).cpu().detach().numpy(), 
        marker=".", 
        c="blue",
        alpha=0.3,
    )

plt.scatter(x_context.cpu().detach().numpy(), y_context.cpu().detach().numpy(), marker="o", c="red")

plt.show()

# %%
import numpy as np
from sklearn.manifold import TSNE

X = np.array([m[0] for m in mus])
X_embedded = TSNE(n_components=2).fit_transform(X)

plt.hist2d(X_embedded[:, 0], X_embedded[:, 1], bins=100, cmap="inferno")
plt.show()
