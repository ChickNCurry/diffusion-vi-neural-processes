# %%
import metalearning_benchmarks.line_sine1d_benchmark
import torch
import wandb
from diffusion import DiffusionNeuralProcess
from diffu_vi_np_train_val import train_and_validate
from diffusion import DDS
from matplotlib import pyplot as plt
from metalearning_benchmarks.line_sine1d_benchmark import LineSine1D
from neural_process import NeuralProcess
from utils import (Config, DataConfig, DataModule, MetaLearningDataset,
                   ModelConfig, TrainValConfig, split_context_target)
from visualize import visualize_batch_1d

# %%
device = None

try:
    import torch_directml
    device = torch_directml.device()
except ModuleNotFoundError:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
print(device)
# Out:
# privateuseone:0

# %%
data_config = DataConfig(
    benchmark="LineSine1D",
    n_task=4096,
    n_datapoints_per_task=64,
    output_noise=0.1,
    seed_task=1237, 
    seed_x=123, 
    seed_noise=1237
)

model_config = ModelConfig(
    x_dim=1,
    y_dim=1,
    r_dim=2,
    z_dim=2,
    h_dim=128,
    num_layers_det_enc=4,
    num_layers_lat_enc=4,
    num_layers_dec=2,
    non_linearity="Tanh",
    is_attentive=False,
    has_latent_path=True,
    has_deterministic_path=False
)

train_val_config = TrainValConfig(
    batch_size=128,
    num_epochs=200,
    learning_rate=3e-4,
    split=(0.8, 0.2)
)

config = Config(
    data_config=data_config,
    model_config=model_config,
    train_val_config=train_val_config
)

# %%
benchmark = getattr(metalearning_benchmarks.line_sine1d_benchmark, config.data_config.benchmark)(
    n_task=config.data_config.n_task,
    n_datapoints_per_task=config.data_config.n_datapoints_per_task,
    output_noise=config.data_config.output_noise,
    seed_task=config.data_config.seed_task, 
    seed_x=config.data_config.seed_x, 
    seed_noise=config.data_config.seed_noise,
)

dataset = MetaLearningDataset(benchmark)

data_module = DataModule(
    batch_size=config.train_val_config.batch_size,
    dataset_and_split=(dataset, config.train_val_config.split),
    num_workers=15
)
# Out:
# Generating tasks: 100%|██████████| 4096/4096 [00:00<00:00, 291500.43it/s]

# %%
visualize_batch_1d(batch=next(iter(data_module.train_dataloader())))

# %%
np_model = NeuralProcess(**config.model_config.asdict()).to(device)
diffu_model = DDS(device=device, num_steps=32, z_dim=2, h_dim=64, beta_start=0.0001, beta_end=0.02, std_0=torch.tensor(1.0)).to(device)
diffu_vi_np_model = DiffusionNeuralProcess(np_model, diffu_model).to(device)

optimizer = torch.optim.Adam(diffu_vi_np_model.parameters(), lr=config.train_val_config.learning_rate)

# %%
wandb_logging = True
if wandb_logging:
    wandb.init(project="diffu-vi-np", config=config.asdict())
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: max-burzer (max-burzer-karlsruhe-institute-of-technology). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.0
# Run data is saved locally in <code>/home/chickencurry/diffusion-vi-neural-processes/neural-process/code/np/wandb/run-20240929_203942-d78ebr25</code>
# Syncing run <strong><a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np/runs/d78ebr25' target="_blank">laced-plasma-25</a></strong> to <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np</a>
#  View run at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np/runs/d78ebr25' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/diffu-vi-np/runs/d78ebr25</a>

# %%
avg_train_log_likes = []
avg_train_diffu_loss = []

avg_val_log_likes = []
avg_val_diffu_loss = []

# %%
losses = train_and_validate(
    diffu_vi_np_model=diffu_vi_np_model,
    data_module=data_module,
    num_epochs=config.train_val_config.num_epochs,
    device=device,
    optimizer=optimizer,
    wandb_logging=wandb_logging,
)

avg_train_log_likes.extend(losses[0])
avg_train_diffu_loss.extend(losses[1])

avg_val_log_likes.extend(losses[2])
avg_val_diffu_loss.extend(losses[3])
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]/home/chickencurry/miniconda3/envs/directml/lib/python3.11/site-packages/torch/optim/adam.py:522: UserWarning: The operator 'aten::_foreach_lerp_.Scalar' is not currently supported on the DML backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /__w/1/s/pytorch-directml-plugin/torch_directml/csrc/dml/dml_cpu_fallback.cpp:15.)
#   torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
# 100%|██████████| 26/26 [00:21<00:00,  1.19it/s, diffu_loss=-3.33e+4, epoch=0, log_like=-227, loss=3.36e+4]
# 100%|██████████| 7/7 [00:03<00:00,  1.82it/s, diffu_loss=-3.46e+4, epoch=0, log_like=-262, loss=3.49e+4]
# 100%|██████████| 26/26 [00:19<00:00,  1.33it/s, diffu_loss=-5.22e+3, epoch=1, log_like=-174, loss=5.39e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.85it/s, diffu_loss=-3.8e+3, epoch=1, log_like=-189, loss=3.98e+3]
# 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, diffu_loss=-3.75e+3, epoch=2, log_like=-176, loss=3.93e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.74it/s, diffu_loss=-4.02e+3, epoch=2, log_like=-184, loss=4.2e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.31it/s, diffu_loss=-3.49e+3, epoch=3, log_like=-185, loss=3.67e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.83it/s, diffu_loss=-3.48e+3, epoch=3, log_like=-183, loss=3.66e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, diffu_loss=-3.34e+3, epoch=4, log_like=-177, loss=3.51e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.83it/s, diffu_loss=-3.38e+3, epoch=4, log_like=-182, loss=3.56e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.33it/s, diffu_loss=-3.23e+3, epoch=5, log_like=-184, loss=3.41e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.68it/s, diffu_loss=-3.18e+3, epoch=5, log_like=-182, loss=3.36e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.31it/s, diffu_loss=-3.56e+3, epoch=6, log_like=-182, loss=3.74e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.82it/s, diffu_loss=-3.74e+3, epoch=6, log_like=-182, loss=3.92e+3]
# 100%|██████████| 26/26 [00:20<00:00,  1.30it/s, diffu_loss=-3.27e+3, epoch=7, log_like=-177, loss=3.44e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.74it/s, diffu_loss=-3.19e+3, epoch=7, log_like=-182, loss=3.37e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.31it/s, diffu_loss=-3.69e+3, epoch=8, log_like=-178, loss=3.87e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.80it/s, diffu_loss=-3.34e+3, epoch=8, log_like=-182, loss=3.52e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.22it/s, diffu_loss=-3.2e+3, epoch=9, log_like=-179, loss=3.38e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.56it/s, diffu_loss=-2.99e+3, epoch=9, log_like=-182, loss=3.17e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.17it/s, diffu_loss=-3.25e+3, epoch=10, log_like=-176, loss=3.42e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.49it/s, diffu_loss=-3.35e+3, epoch=10, log_like=-182, loss=3.53e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.14it/s, diffu_loss=-2.98e+3, epoch=11, log_like=-171, loss=3.14e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.57it/s, diffu_loss=-3.48e+3, epoch=11, log_like=-182, loss=3.66e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.15it/s, diffu_loss=-3.87e+3, epoch=12, log_like=-175, loss=4.04e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.45it/s, diffu_loss=-2.86e+3, epoch=12, log_like=-182, loss=3.04e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.18it/s, diffu_loss=-3.69e+3, epoch=13, log_like=-183, loss=3.87e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.50it/s, diffu_loss=-3.89e+3, epoch=13, log_like=-182, loss=4.07e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.20it/s, diffu_loss=-2.82e+3, epoch=14, log_like=-182, loss=3e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.58it/s, diffu_loss=-3.67e+3, epoch=14, log_like=-182, loss=3.85e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.23it/s, diffu_loss=-3.43e+3, epoch=15, log_like=-177, loss=3.6e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.64it/s, diffu_loss=-3.46e+3, epoch=15, log_like=-182, loss=3.64e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.18it/s, diffu_loss=-3.58e+3, epoch=16, log_like=-180, loss=3.76e+3]
# 100%|██████████| 7/7 [00:05<00:00,  1.37it/s, diffu_loss=-3.33e+3, epoch=16, log_like=-182, loss=3.51e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.14it/s, diffu_loss=-3.62e+3, epoch=17, log_like=-177, loss=3.79e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.55it/s, diffu_loss=-3.32e+3, epoch=17, log_like=-182, loss=3.5e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.15it/s, diffu_loss=-3.79e+3, epoch=18, log_like=-177, loss=3.97e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.48it/s, diffu_loss=-3.12e+3, epoch=18, log_like=-182, loss=3.3e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.23it/s, diffu_loss=-3.54e+3, epoch=19, log_like=-180, loss=3.72e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.63it/s, diffu_loss=-2.88e+3, epoch=19, log_like=-181, loss=3.06e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.23it/s, diffu_loss=-3.79e+3, epoch=20, log_like=-179, loss=3.96e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.62it/s, diffu_loss=-3.16e+3, epoch=20, log_like=-181, loss=3.33e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.17it/s, diffu_loss=-3.37e+3, epoch=21, log_like=-182, loss=3.55e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.55it/s, diffu_loss=-3.1e+3, epoch=21, log_like=-181, loss=3.27e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.17it/s, diffu_loss=-3.39e+3, epoch=22, log_like=-187, loss=3.57e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.43it/s, diffu_loss=-3.58e+3, epoch=22, log_like=-181, loss=3.76e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.14it/s, diffu_loss=-2.88e+3, epoch=23, log_like=-171, loss=3.05e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.46it/s, diffu_loss=-2.66e+3, epoch=23, log_like=-180, loss=2.84e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.16it/s, diffu_loss=-4.06e+3, epoch=24, log_like=-179, loss=4.24e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.47it/s, diffu_loss=-2.69e+3, epoch=24, log_like=-180, loss=2.87e+3]
# 100%|██████████| 26/26 [00:22<00:00,  1.16it/s, diffu_loss=-3.68e+3, epoch=25, log_like=-182, loss=3.86e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.50it/s, diffu_loss=-3.38e+3, epoch=25, log_like=-179, loss=3.55e+3]
# 100%|██████████| 26/26 [00:23<00:00,  1.13it/s, diffu_loss=-3.69e+3, epoch=26, log_like=-185, loss=3.87e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.44it/s, diffu_loss=-3.66e+3, epoch=26, log_like=-179, loss=3.84e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.30it/s, diffu_loss=-3.84e+3, epoch=27, log_like=-180, loss=4.02e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.87it/s, diffu_loss=-3.96e+3, epoch=27, log_like=-178, loss=4.14e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, diffu_loss=-3.77e+3, epoch=28, log_like=-176, loss=3.95e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.85it/s, diffu_loss=-4.1e+3, epoch=28, log_like=-177, loss=4.27e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.32it/s, diffu_loss=-3.46e+3, epoch=29, log_like=-165, loss=3.62e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.67it/s, diffu_loss=-3.8e+3, epoch=29, log_like=-177, loss=3.97e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, diffu_loss=-3.55e+3, epoch=30, log_like=-168, loss=3.71e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.84it/s, diffu_loss=-3.24e+3, epoch=30, log_like=-176, loss=3.42e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, diffu_loss=-3.02e+3, epoch=31, log_like=-171, loss=3.19e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.85it/s, diffu_loss=-3.53e+3, epoch=31, log_like=-175, loss=3.7e+3]
# 100%|██████████| 26/26 [00:18<00:00,  1.37it/s, diffu_loss=-2.96e+3, epoch=32, log_like=-188, loss=3.15e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.85it/s, diffu_loss=-3.35e+3, epoch=32, log_like=-174, loss=3.52e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.34it/s, diffu_loss=-3.96e+3, epoch=33, log_like=-176, loss=4.14e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.83it/s, diffu_loss=-3.62e+3, epoch=33, log_like=-174, loss=3.79e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.34it/s, diffu_loss=-3.43e+3, epoch=34, log_like=-169, loss=3.6e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.81it/s, diffu_loss=-3.43e+3, epoch=34, log_like=-173, loss=3.6e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, diffu_loss=-4e+3, epoch=35, log_like=-170, loss=4.17e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.80it/s, diffu_loss=-3.68e+3, epoch=35, log_like=-173, loss=3.85e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.19it/s, diffu_loss=-3.12e+3, epoch=36, log_like=-173, loss=3.29e+3]
# 100%|██████████| 7/7 [00:05<00:00,  1.37it/s, diffu_loss=-3.59e+3, epoch=36, log_like=-173, loss=3.76e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.19it/s, diffu_loss=-3.51e+3, epoch=37, log_like=-170, loss=3.67e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.85it/s, diffu_loss=-3.53e+3, epoch=37, log_like=-172, loss=3.7e+3]
# 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, diffu_loss=-2.32e+3, epoch=38, log_like=-171, loss=2.49e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.81it/s, diffu_loss=-3.21e+3, epoch=38, log_like=-172, loss=3.38e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, diffu_loss=-3.07e+3, epoch=39, log_like=-163, loss=3.23e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.70it/s, diffu_loss=-3.17e+3, epoch=39, log_like=-172, loss=3.34e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.37it/s, diffu_loss=-2.89e+3, epoch=40, log_like=-170, loss=3.06e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.89it/s, diffu_loss=-3.01e+3, epoch=40, log_like=-172, loss=3.18e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.34it/s, diffu_loss=-3.03e+3, epoch=41, log_like=-172, loss=3.2e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.75it/s, diffu_loss=-2.94e+3, epoch=41, log_like=-172, loss=3.11e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, diffu_loss=-2.83e+3, epoch=42, log_like=-168, loss=3e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.86it/s, diffu_loss=-3.11e+3, epoch=42, log_like=-172, loss=3.27e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.33it/s, diffu_loss=-2.95e+3, epoch=43, log_like=-175, loss=3.13e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.82it/s, diffu_loss=-2.57e+3, epoch=43, log_like=-172, loss=2.74e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.34it/s, diffu_loss=-3.24e+3, epoch=44, log_like=-167, loss=3.4e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.67it/s, diffu_loss=-2.81e+3, epoch=44, log_like=-171, loss=2.98e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, diffu_loss=-3.2e+3, epoch=45, log_like=-170, loss=3.37e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.88it/s, diffu_loss=-2.52e+3, epoch=45, log_like=-172, loss=2.69e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, diffu_loss=-3.21e+3, epoch=46, log_like=-173, loss=3.38e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.86it/s, diffu_loss=-2.74e+3, epoch=46, log_like=-172, loss=2.91e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.32it/s, diffu_loss=-2.99e+3, epoch=47, log_like=-168, loss=3.16e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.84it/s, diffu_loss=-3.02e+3, epoch=47, log_like=-172, loss=3.19e+3]
# 100%|██████████| 26/26 [00:18<00:00,  1.37it/s, diffu_loss=-3.6e+3, epoch=48, log_like=-166, loss=3.76e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.66it/s, diffu_loss=-2.65e+3, epoch=48, log_like=-171, loss=2.82e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, diffu_loss=-3.04e+3, epoch=49, log_like=-175, loss=3.21e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.84it/s, diffu_loss=-3.73e+3, epoch=49, log_like=-172, loss=3.9e+3]
# 100%|██████████| 26/26 [00:19<00:00,  1.32it/s, diffu_loss=-2.88e+3, epoch=50, log_like=-168, loss=3.05e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.86it/s, diffu_loss=-2.92e+3, epoch=50, log_like=-172, loss=3.09e+3]
# 100%|██████████| 26/26 [00:18<00:00,  1.37it/s, diffu_loss=-3.1e+3, epoch=51, log_like=-174, loss=3.27e+3]
# 100%|██████████| 7/7 [00:03<00:00,  1.81it/s, diffu_loss=-3.51e+3, epoch=51, log_like=-171, loss=3.68e+3]
# 100%|██████████| 26/26 [00:20<00:00,  1.27it/s, diffu_loss=-3.62e+3, epoch=52, log_like=-165, loss=3.78e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.68it/s, diffu_loss=-3.22e+3, epoch=52, log_like=-171, loss=3.39e+3]
# 100%|██████████| 26/26 [00:20<00:00,  1.27it/s, diffu_loss=-3.12e+3, epoch=53, log_like=-171, loss=3.29e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.53it/s, diffu_loss=-3.1e+3, epoch=53, log_like=-171, loss=3.27e+3]
# 100%|██████████| 26/26 [00:21<00:00,  1.23it/s, diffu_loss=-4.51e+3, epoch=54, log_like=-175, loss=4.68e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.73it/s, diffu_loss=-2.8e+3, epoch=54, log_like=-171, loss=2.97e+3]
# 100%|██████████| 26/26 [00:20<00:00,  1.28it/s, diffu_loss=-3.63e+3, epoch=55, log_like=-167, loss=3.79e+3]
# 100%|██████████| 7/7 [00:04<00:00,  1.59it/s, diffu_loss=-3.26e+3, epoch=55, log_like=-171, loss=3.43e+3]
#  62%|██████▏   | 16/26 [00:13<00:08,  1.20it/s, diffu_loss=-2.88e+3, epoch=56, log_like=-172, loss=3.05e+3]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 losses = train_and_validate(
#       2     diffu_vi_np_model=diffu_vi_np_model,
#       3     data_module=data_module,
#       4     num_epochs=config.train_val_config.num_epochs,
#       5     device=device,
#       6     optimizer=optimizer,
#       7     wandb_logging=wandb_logging,
#       8 )
#      10 avg_train_log_likes.extend(losses[0])
#      11 avg_train_diffu_loss.extend(losses[1])
#
# File ~/diffusion-vi-neural-processes/neural-process/code/np/diffu_vi_np_train_val.py:48, in train_and_validate(diffu_vi_np_model, device, data_module, optimizer, num_epochs, wandb_logging, preprocessing)
#      44 loop = tqdm(dataloader, total=len(dataloader))
#      46 for batch in loop:
# ---> 48     loss, log_like, diffu_loss = step(
#      49         diffu_vi_np_model, device, batch, preprocessing
#      50     )
#      52     optimizer.zero_grad()
#      53     loss.backward()  # type: ignore
#
# File ~/diffusion-vi-neural-processes/neural-process/code/np/diffu_vi_np_train_val.py:156, in step(diffu_vi_np_model, device, batch, preprocessing)
#     153 b_t_list: List[Tensor] = []
#     155 for t in range(1, diffu_vi_np_model.diffu_model.num_steps + 1):
# --> 156     z_D_t, z_mu_D_t, z_std_D_t = diffu_vi_np_model.diffu_model.forward_transition(
#     157         tuples_D[t - 1][0], torch.tensor([t - 1]).to(device)
#     158     )
#     160     z_C_t, z_mu_C_t, z_std_C_t = diffu_vi_np_model.diffu_model.forward_transition(
#     161         tuples_C[t - 1][0], torch.tensor([t - 1]).to(device)
#     162     )
#     164     tuples_D.append((z_D_t, z_mu_D_t, z_std_D_t))
#
# File ~/diffusion-vi-neural-processes/neural-process/code/np/diffusion.py:51, in DiffusionVariant.forward_transition(self, z, t)
#      48 z_mean = self.forward_mean(z, t)
#      49 # (batch_size, z_dim)
# ---> 51 z_var = self.forward_var(t)
#      52 # (1)
#      54 z_next = self.reparameterize(z_mean, z_var)
#
# File ~/diffusion-vi-neural-processes/neural-process/code/np/diffusion.py:175, in DDS.forward_var(self, t)
#     172 beta_t = self.betas[t.int()]
#     173 # (1)
# --> 175 z_var = beta_t * torch.pow(self.std_0, 2) * self.delta_t
#     176 # (1)
#     178 return z_var
#
# KeyboardInterrupt:

# %%
_, ax = plt.subplots(1, 2, figsize=(12, 3))

ax[0].plot(avg_train_log_likes, label="train")
ax[0].plot(avg_val_log_likes, label="val")
ax[0].set_title("Log Likelihood")
ax[0].grid()
ax[0].legend()

ax[1].plot(avg_train_diffu_loss, label="train")
ax[1].plot(avg_val_diffu_loss, label="val")
ax[1].set_title("Diffusion Loss")
ax[1].grid()
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
gen_dataloader = torch.utils.data.DataLoader(dataset=dataset, batch_size=1, shuffle=True)
x_data, y_data = next(iter(gen_dataloader))
x_data = x_data.to(device)
y_data = y_data.to(device)

# %%
context_lens = [1, 2, 3, 4, 5] # x_data.shape[1] - 1

n_samples = 512

fig, ax  = plt.subplots(len(context_lens), 2, figsize=(8, 2 * len(context_lens)), gridspec_kw={'width_ratios': [4, 1]})
fig.suptitle(f"{n_samples} Samples on {config.data_config.benchmark} Benchmark with 2d Latent Space")

for i, context_len in enumerate(context_lens):

    x_context, y_context, _, _ = split_context_target(x_data, y_data, context_len=context_len, random=False)
    
    diffu_vi_np_model.eval()
    with torch.no_grad():
        
        _, y_mu, _, z, _, _ = diffu_vi_np_model.sample(x_context, y_context, x_data, n_samples)

        x_data_sorted, indices = x_data.sort(dim=1)
        indices = indices.squeeze(0).squeeze(1)
        x_data_sorted = x_data_sorted.cpu().detach().numpy()
        y_data_sorted = y_data[:, indices, :].cpu().detach().numpy()
        y_mu_sorted = y_mu[:, indices, :].cpu().detach().numpy()

        for k in range(n_samples):
            ax[i][0].plot(x_data_sorted.squeeze(0).squeeze(1), y_mu_sorted[k].squeeze(1), alpha=0.2, c="tab:blue", zorder=0)

        ax[i][0].scatter(x_data_sorted, y_data_sorted, marker="o", c="black", zorder=1)
        ax[i][0].scatter(x_context.cpu().detach().numpy(), y_context.cpu().detach().numpy(), marker="X", c="red", s=100, zorder=2)

        ax[i][1].hist2d(z[:, 0].cpu().detach().numpy(), z[:, 1].cpu().detach().numpy(), bins=20, cmap="inferno")
        
        # ax[i][1].set_xlim(-10, 10)
        # ax[i][1].set_ylim(-10, 10)
        # if i != 0:
        #     ax[i][1].sharex(ax[0][1])
        #     ax[i][1].sharey(ax[0][1])


plt.tight_layout()
plt.show()
